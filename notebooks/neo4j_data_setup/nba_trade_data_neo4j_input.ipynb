# %% [markdown]
# * ingesting docs into neo4j
# https://neo4j.com/developer-blog/ingest-documents-neo4j-milvus/
# * Inspired by:
# https://neo4j.com/developer-blog/graphrag-agent-neo4j-milvus/
#
# easy example:
# https://www.linkedin.com/pulse/getting-started-knowledge-graphs-llm-dale-lewis-unb8e/

# %% [markdown]
# connection details:
# /workspaces/custom_ollama_docker/neo4j_setup/Neo4j-faf0297f-Created-2024-10-09.txt

# %%
import pandas as pd

nba_player_inflated_data = pd.read_csv('../../data/neo4j/raw/nba_player_data_final_inflated.csv')

print(nba_player_inflated_data)



llm = 'tomasonjo/llama3-text2cypher-demo'
# Out:
#        Season           Player        Position   Age Team        TeamID  \
# 0     2018-19     Aaron Gordon         Forward  23.0  ORL  1.610613e+09
# 1     2018-19    Aaron Holiday           Guard  22.0  IND  1.610613e+09
# 2     2018-19      Abdel Nader         Forward  25.0  OKC  1.610613e+09
# 3     2018-19       Al Horford  Center-Forward  33.0  BOS  1.610613e+09
# 4     2018-19  Al-Farouq Aminu         Forward  28.0  POR  1.610613e+09
# ...       ...              ...             ...   ...  ...           ...
# 2780  2023-24      Zach LaVine           Guard  29.0  CHI  1.610613e+09
# 2781  2023-24   Zavier Simpson           Guard  27.0  MEM  0.000000e+00
# 2782  2023-24       Zeke Nnaji  Forward-Center  23.0  DEN  1.610613e+09
# 2783  2023-24  Ziaire Williams         Forward  22.0  MEM  1.610613e+09
# 2784  2023-24  Zion Williamson         Forward  23.0  NOP  1.610613e+09
#
#       Years of Service    GP    GS      MP  ...  Injury_Risk   Salary Cap  \
# 0                  4.0  78.0  78.0  2633.0  ...     Low Risk  101869000.0
# 1                  0.0  50.0   0.0   646.0  ...     Low Risk  101869000.0
# 2                  2.0  61.0   1.0   694.0  ...     Low Risk  101869000.0
# 3                 11.0  68.0  68.0  1973.0  ...    High Risk  101869000.0
# 4                  8.0  81.0  81.0  2292.0  ...     Low Risk  101869000.0
# ...                ...   ...   ...     ...  ...          ...          ...
# 2780               9.0  25.0  23.0   872.0  ...     Low Risk  136021000.0
# 2781               2.0   7.0   0.0   161.0  ...     Low Risk  136021000.0
# 2782               3.0  58.0   0.0   576.0  ...     Low Risk  136021000.0
# 2783               2.0  51.0  15.0  1038.0  ...     Low Risk  136021000.0
# 2784               4.0  70.0  70.0  2207.0  ...     Low Risk  136021000.0
#
#        Luxury Tax    1st Apron        BAE  Standard /Non-Taxpayer   Taxpayer  \
# 0     123733000.0  129817000.0  3382000.0               8641000.0  5337000.0
# 1     123733000.0  129817000.0  3382000.0               8641000.0  5337000.0
# 2     123733000.0  129817000.0  3382000.0               8641000.0  5337000.0
# 3     123733000.0  129817000.0  3382000.0               8641000.0  5337000.0
# 4     123733000.0  129817000.0  3382000.0               8641000.0  5337000.0
# ...           ...          ...        ...                     ...        ...
# 2780  165294000.0  172346000.0  4516000.0              12405000.0  5000000.0
# 2781  165294000.0  172346000.0  4516000.0              12405000.0  5000000.0
# 2782  165294000.0  172346000.0  4516000.0              12405000.0  5000000.0
# 2783  165294000.0  172346000.0  4516000.0              12405000.0  5000000.0
# 2784  165294000.0  172346000.0  4516000.0              12405000.0  5000000.0
#
#       Team Room /Under Cap  Salary_Cap_Inflated    2nd Apron
# 0                4449000.0         1.187242e+08          NaN
# 1                4449000.0         1.187242e+08          NaN
# 2                4449000.0         1.187242e+08          NaN
# 3                4449000.0         1.187242e+08          NaN
# 4                4449000.0         1.187242e+08          NaN
# ...                    ...                  ...          ...
# 2780             7723000.0         1.306431e+08  182794000.0
# 2781             7723000.0         1.306431e+08  182794000.0
# 2782             7723000.0         1.306431e+08  182794000.0
# 2783             7723000.0         1.306431e+08  182794000.0
# 2784             7723000.0         1.306431e+08  182794000.0
#
# [2785 rows x 66 columns]

# %% [markdown]
# # clean data before entry into Neo4j

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Check for missing values in the entire dataset
missing_values_summary = nba_player_inflated_data.isnull().sum()
print("Missing Values Summary:")
print(missing_values_summary)


# Remove the '2nd Apron' column from the DataFrame
nba_player_inflated_data = nba_player_inflated_data.drop(columns=['2nd Apron'])

# Replace missing values in 'Injury_Periods' with 'Not_injured'
nba_player_inflated_data['Injury_Periods'] = nba_player_inflated_data['Injury_Periods'].fillna("Not_injured")

# Drop all remaining rows with any other missing values
nba_player_inflated_data_cleaned = nba_player_inflated_data.dropna()

# Display the count of missing values after cleaning
missing_values_after_cleaning = nba_player_inflated_data_cleaned.isnull().sum()

# Step 1: Map unique teams to unique TeamID values
team_id_mapping = {
    "ATL": 1610612737, "BOS": 1610612738, "BKN": 1610612751, "CHA": 1610612766,
    "CHI": 1610612741, "CLE": 1610612739, "DAL": 1610612742, "DEN": 1610612743,
    "DET": 1610612765, "GSW": 1610612744, "HOU": 1610612745, "IND": 1610612754,
    "LAC": 1610612746, "LAL": 1610612747, "MEM": 1610612763, "MIA": 1610612748,
    "MIL": 1610612749, "MIN": 1610612750, "NOP": 1610612740, "NYK": 1610612752,
    "OKC": 1610612760, "ORL": 1610612753, "PHI": 1610612755, "PHX": 1610612756,
    "POR": 1610612757, "SAC": 1610612758, "SAS": 1610612759, "TOR": 1610612761,
    "UTA": 1610612762, "WAS": 1610612764
}

# Step 2: Apply the mapping to update TeamID values
nba_player_inflated_data_cleaned['TeamID'] = nba_player_inflated_data_cleaned['Team'].map(team_id_mapping)


# Display the data types and missing values for each column
print("Data Types and Missing Values:")
print(nba_player_inflated_data.info())  # Provides data type and non-null count

# Generate a descriptive statistics summary to spot anomalies
print("\nDescriptive Statistics of the Dataset:")
print(nba_player_inflated_data.describe(include='all'))  # Shows statistics for all columns, including categorical


# Check for unique value counts in key columns to identify anomalies
unique_counts = nba_player_inflated_data.nunique()
print("\nUnique Value Counts for Key Columns:")
print(unique_counts)

# Check if any of the key columns have unexpected unique values
print(f"\nUnique Players: {nba_player_inflated_data['Player'].nunique()}")
print(f"Unique Seasons: {nba_player_inflated_data['Season'].nunique()}")
print(f"Unique Teams: {nba_player_inflated_data['Team'].nunique()}")
print(f"Unique Contracts (based on Salary): {nba_player_inflated_data['Salary'].nunique()}")

# Check for duplicates based on a combination of key columns
duplicates = nba_player_inflated_data.duplicated(subset=["Player", "Season", "Salary"])
print(f"\nNumber of Duplicate Rows Based on [Player, Season, Salary]: {duplicates.sum()}")

# Display rows that are duplicated to investigate further
if duplicates.sum() > 0:
    print("Duplicate Rows Based on [Player, Season, Salary]:")
    print(nba_player_inflated_data[duplicates])

# Validate data types and summary statistics
print("Final Dataset Overview:")
print(nba_player_inflated_data_cleaned.info())
print("\nFinal Dataset Descriptive Statistics:")
print(nba_player_inflated_data_cleaned.describe(include='all'))

# Preview the first few rows of the cleaned dataset
print("\nPreview of Cleaned Dataset:")
print(nba_player_inflated_data_cleaned.head())
# Out:
# Missing Values Summary:
# Season                       0
# Player                       0
# Position                     0
# Age                          0
# Team                         0
#                           ...
# Standard /Non-Taxpayer       0
# Taxpayer                     0
# Team Room /Under Cap         0
# Salary_Cap_Inflated          0
# 2nd Apron                 2299
# Length: 66, dtype: int64
# Data Types and Missing Values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2785 entries, 0 to 2784
# Data columns (total 65 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Season                  2785 non-null   object
#  1   Player                  2785 non-null   object
#  2   Position                2785 non-null   object
#  3   Age                     2785 non-null   float64
#  4   Team                    2785 non-null   object
#  5   TeamID                  2785 non-null   float64
#  6   Years of Service        2785 non-null   float64
#  7   GP                      2785 non-null   float64
#  8   GS                      2785 non-null   float64
#  9   MP                      2785 non-null   float64
#  10  FG                      2785 non-null   float64
#  11  FGA                     2785 non-null   float64
#  12  FG%                     2785 non-null   float64
#  13  3P                      2785 non-null   float64
#  14  3PA                     2785 non-null   float64
#  15  3P%                     2681 non-null   float64
#  16  2P                      2785 non-null   float64
#  17  2PA                     2785 non-null   float64
#  18  2P%                     2780 non-null   float64
#  19  eFG%                    2785 non-null   float64
#  20  FT                      2785 non-null   float64
#  21  FTA                     2785 non-null   float64
#  22  FT%                     2713 non-null   float64
#  23  ORB                     2785 non-null   float64
#  24  DRB                     2785 non-null   float64
#  25  TRB                     2785 non-null   float64
#  26  AST                     2785 non-null   float64
#  27  STL                     2785 non-null   float64
#  28  BLK                     2785 non-null   float64
#  29  TOV                     2785 non-null   float64
#  30  PF                      2785 non-null   float64
#  31  PTS                     2785 non-null   float64
#  32  PER                     2758 non-null   float64
#  33  TS%                     2758 non-null   float64
#  34  ORB%                    2758 non-null   float64
#  35  DRB%                    2758 non-null   float64
#  36  TRB%                    2758 non-null   float64
#  37  AST%                    2758 non-null   float64
#  38  STL%                    2758 non-null   float64
#  39  BLK%                    2758 non-null   float64
#  40  TOV%                    2758 non-null   float64
#  41  USG%                    2758 non-null   float64
#  42  OWS                     2758 non-null   float64
#  43  DWS                     2758 non-null   float64
#  44  WS                      2758 non-null   float64
#  45  WS/48                   2758 non-null   float64
#  46  OBPM                    2758 non-null   float64
#  47  DBPM                    2758 non-null   float64
#  48  BPM                     2758 non-null   float64
#  49  VORP                    2758 non-null   float64
#  50  Wins                    2615 non-null   float64
#  51  Losses                  2615 non-null   float64
#  52  Salary                  2785 non-null   float64
#  53  Injured                 2785 non-null   bool
#  54  Injury_Periods          2785 non-null   object
#  55  Total_Days_Injured      2785 non-null   float64
#  56  Injury_Risk             2785 non-null   object
#  57  Salary Cap              2785 non-null   float64
#  58  Luxury Tax              2785 non-null   float64
#  59  1st Apron               2785 non-null   float64
#  60  BAE                     2785 non-null   float64
#  61  Standard /Non-Taxpayer  2785 non-null   float64
#  62  Taxpayer                2785 non-null   float64
#  63  Team Room /Under Cap    2785 non-null   float64
#  64  Salary_Cap_Inflated     2785 non-null   float64
# dtypes: bool(1), float64(58), object(6)
# memory usage: 1.4+ MB
# None
#
# Descriptive Statistics of the Dataset:
#          Season        Player Position          Age  Team        TeamID  \
# count      2785          2785     2785  2785.000000  2785  2.785000e+03
# unique        6           888        7          NaN    30           NaN
# top     2023-24  Aaron Gordon    Guard          NaN   UTA           NaN
# freq        486             6     1086          NaN   105           NaN
# mean        NaN           NaN      NaN    26.290485   NaN  1.512299e+09
# std         NaN           NaN      NaN     4.244164   NaN  3.856597e+08
# min         NaN           NaN      NaN    19.000000   NaN  0.000000e+00
# 25%         NaN           NaN      NaN    23.000000   NaN  1.610613e+09
# 50%         NaN           NaN      NaN    26.000000   NaN  1.610613e+09
# 75%         NaN           NaN      NaN    29.000000   NaN  1.610613e+09
# max         NaN           NaN      NaN    43.000000   NaN  1.610613e+09
#
#         Years of Service           GP           GS           MP  ...  \
# count        2785.000000  2785.000000  2785.000000  2785.000000  ...
# unique               NaN          NaN          NaN          NaN  ...
# top                  NaN          NaN          NaN          NaN  ...
# freq                 NaN          NaN          NaN          NaN  ...
# mean            4.530700    45.675763    22.208618  1050.681867  ...
# std             4.180535    23.315153    26.219110   783.814179  ...
# min             0.000000     1.000000     0.000000    15.000000  ...
# 25%             1.000000    26.000000     1.000000   323.000000  ...
# 50%             3.000000    49.000000     8.000000   958.000000  ...
# 75%             7.000000    66.000000    43.000000  1700.000000  ...
# max            21.000000    82.000000    82.000000  3028.000000  ...
#
#         Total_Days_Injured  Injury_Risk    Salary Cap    Luxury Tax  \
# count          2785.000000         2785  2.785000e+03  2.785000e+03
# unique                 NaN            3           NaN           NaN
# top                    NaN     Low Risk           NaN           NaN
# freq                   NaN         1599           NaN           NaN
# mean            176.874327          NaN  1.156375e+08  1.405138e+08
# std             692.093570          NaN  1.137599e+07  1.383604e+07
# min               0.000000          NaN  1.018690e+08  1.237330e+08
# 25%               0.000000          NaN  1.091400e+08  1.326270e+08
# 50%               4.000000          NaN  1.124140e+08  1.366060e+08
# 75%              32.000000          NaN  1.236550e+08  1.502670e+08
# max            7674.000000          NaN  1.360210e+08  1.652940e+08
#
#            1st Apron           BAE  Standard /Non-Taxpayer      Taxpayer  \
# count   2.785000e+03  2.785000e+03            2.785000e+03  2.785000e+03
# unique           NaN           NaN                     NaN           NaN
# top              NaN           NaN                     NaN           NaN
# freq             NaN           NaN                     NaN           NaN
# mean    1.469963e+08  3.838945e+06            9.960550e+06  5.687513e+06
# std     1.415752e+07  3.777748e+05            1.250164e+06  4.627510e+05
# min     1.298170e+08  3.382000e+06            8.641000e+06  5.000000e+06
# 25%     1.389280e+08  3.623000e+06            9.258000e+06  5.337000e+06
# 50%     1.430020e+08  3.732000e+06            9.536000e+06  5.718000e+06
# 75%     1.569830e+08  4.105000e+06            1.049000e+07  5.890000e+06
# max     1.723460e+08  4.516000e+06            1.240500e+07  6.479000e+06
#
#         Team Room /Under Cap  Salary_Cap_Inflated
# count           2.785000e+03         2.785000e+03
# unique                   NaN                  NaN
# top                      NaN                  NaN
# freq                     NaN                  NaN
# mean            5.361682e+06         1.238493e+08
# std             1.121809e+06         3.680857e+06
# min             4.449000e+06         1.187242e+08
# 25%             4.767000e+06         1.214102e+08
# 50%             4.910000e+06         1.234119e+08
# 75%             5.401000e+06         1.249345e+08
# max             7.723000e+06         1.306431e+08
#
# [11 rows x 65 columns]
#
# Unique Value Counts for Key Columns:
# Season                      6
# Player                    888
# Position                    7
# Age                        25
# Team                       30
#                          ...
# BAE                         5
# Standard /Non-Taxpayer      5
# Taxpayer                    5
# Team Room /Under Cap        5
# Salary_Cap_Inflated         6
# Length: 65, dtype: int64
#
# Unique Players: 888
# Unique Seasons: 6
# Unique Teams: 30
# Unique Contracts (based on Salary): 1729
#
# Number of Duplicate Rows Based on [Player, Season, Salary]: 0
# Final Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2449 entries, 0 to 2784
# Data columns (total 65 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Season                  2449 non-null   object
#  1   Player                  2449 non-null   object
#  2   Position                2449 non-null   object
#  3   Age                     2449 non-null   float64
#  4   Team                    2449 non-null   object
#  5   TeamID                  2449 non-null   int64
#  6   Years of Service        2449 non-null   float64
#  7   GP                      2449 non-null   float64
#  8   GS                      2449 non-null   float64
#  9   MP                      2449 non-null   float64
#  10  FG                      2449 non-null   float64
#  11  FGA                     2449 non-null   float64
#  12  FG%                     2449 non-null   float64
#  13  3P                      2449 non-null   float64
#  14  3PA                     2449 non-null   float64
#  15  3P%                     2449 non-null   float64
#  16  2P                      2449 non-null   float64
#  17  2PA                     2449 non-null   float64
#  18  2P%                     2449 non-null   float64
#  19  eFG%                    2449 non-null   float64
#  20  FT                      2449 non-null   float64
#  21  FTA                     2449 non-null   float64
#  22  FT%                     2449 non-null   float64
#  23  ORB                     2449 non-null   float64
#  24  DRB                     2449 non-null   float64
#  25  TRB                     2449 non-null   float64
#  26  AST                     2449 non-null   float64
#  27  STL                     2449 non-null   float64
#  28  BLK                     2449 non-null   float64
#  29  TOV                     2449 non-null   float64
#  30  PF                      2449 non-null   float64
#  31  PTS                     2449 non-null   float64
#  32  PER                     2449 non-null   float64
#  33  TS%                     2449 non-null   float64
#  34  ORB%                    2449 non-null   float64
#  35  DRB%                    2449 non-null   float64
#  36  TRB%                    2449 non-null   float64
#  37  AST%                    2449 non-null   float64
#  38  STL%                    2449 non-null   float64
#  39  BLK%                    2449 non-null   float64
#  40  TOV%                    2449 non-null   float64
#  41  USG%                    2449 non-null   float64
#  42  OWS                     2449 non-null   float64
#  43  DWS                     2449 non-null   float64
#  44  WS                      2449 non-null   float64
#  45  WS/48                   2449 non-null   float64
#  46  OBPM                    2449 non-null   float64
#  47  DBPM                    2449 non-null   float64
#  48  BPM                     2449 non-null   float64
#  49  VORP                    2449 non-null   float64
#  50  Wins                    2449 non-null   float64
#  51  Losses                  2449 non-null   float64
#  52  Salary                  2449 non-null   float64
#  53  Injured                 2449 non-null   bool
#  54  Injury_Periods          2449 non-null   object
#  55  Total_Days_Injured      2449 non-null   float64
#  56  Injury_Risk             2449 non-null   object
#  57  Salary Cap              2449 non-null   float64
#  58  Luxury Tax              2449 non-null   float64
#  59  1st Apron               2449 non-null   float64
#  60  BAE                     2449 non-null   float64
#  61  Standard /Non-Taxpayer  2449 non-null   float64
#  62  Taxpayer                2449 non-null   float64
#  63  Team Room /Under Cap    2449 non-null   float64
#  64  Salary_Cap_Inflated     2449 non-null   float64
# dtypes: bool(1), float64(57), int64(1), object(6)
# memory usage: 1.2+ MB
# None
#
# Final Dataset Descriptive Statistics:
#          Season        Player Position          Age  Team        TeamID  \
# count      2449          2449     2449  2449.000000  2449  2.449000e+03
# unique        6           783        7          NaN    30           NaN
# top     2023-24  Aaron Gordon    Guard          NaN   GSW           NaN
# freq        421             6      971          NaN    92           NaN
# mean        NaN           NaN      NaN    26.311964   NaN  1.610613e+09
# std         NaN           NaN      NaN     4.284494   NaN  8.663301e+00
# min         NaN           NaN      NaN    19.000000   NaN  1.610613e+09
# 25%         NaN           NaN      NaN    23.000000   NaN  1.610613e+09
# 50%         NaN           NaN      NaN    26.000000   NaN  1.610613e+09
# 75%         NaN           NaN      NaN    29.000000   NaN  1.610613e+09
# max         NaN           NaN      NaN    43.000000   NaN  1.610613e+09
#
#         Years of Service           GP           GS           MP  ...  \
# count        2449.000000  2449.000000  2449.000000  2449.000000  ...
# unique               NaN          NaN          NaN          NaN  ...
# top                  NaN          NaN          NaN          NaN  ...
# freq                 NaN          NaN          NaN          NaN  ...
# mean            4.606370    49.121682    24.354839  1148.657820  ...
# std             4.183327    21.693928    26.674529   766.394152  ...
# min             0.000000     1.000000     0.000000    16.000000  ...
# 25%             1.000000    33.000000     1.000000   458.000000  ...
# 50%             3.000000    53.000000    11.000000  1087.000000  ...
# 75%             7.000000    67.000000    48.000000  1780.000000  ...
# max            21.000000    82.000000    82.000000  3028.000000  ...
#
#         Total_Days_Injured  Injury_Risk    Salary Cap    Luxury Tax  \
# count          2449.000000         2449  2.449000e+03  2.449000e+03
# unique                 NaN            3           NaN           NaN
# top                    NaN     Low Risk           NaN           NaN
# freq                   NaN         1359           NaN           NaN
# mean            184.782360          NaN  1.155903e+08  1.404566e+08
# std             703.665217          NaN  1.133909e+07  1.379109e+07
# min               0.000000          NaN  1.018690e+08  1.237330e+08
# 25%               0.000000          NaN  1.091400e+08  1.326270e+08
# 50%               6.000000          NaN  1.124140e+08  1.366060e+08
# 75%              35.000000          NaN  1.236550e+08  1.502670e+08
# max            7674.000000          NaN  1.360210e+08  1.652940e+08
#
#            1st Apron           BAE  Standard /Non-Taxpayer      Taxpayer  \
# count   2.449000e+03  2.449000e+03            2.449000e+03  2.449000e+03
# unique           NaN           NaN                     NaN           NaN
# top              NaN           NaN                     NaN           NaN
# freq             NaN           NaN                     NaN           NaN
# mean    1.469377e+08  3.837374e+06            9.954294e+06  5.690566e+06
# std     1.411156e+07  3.765502e+05            1.244603e+06  4.627615e+05
# min     1.298170e+08  3.382000e+06            8.641000e+06  5.000000e+06
# 25%     1.389280e+08  3.623000e+06            9.258000e+06  5.337000e+06
# 50%     1.430020e+08  3.732000e+06            9.536000e+06  5.718000e+06
# 75%     1.569830e+08  4.105000e+06            1.049000e+07  5.890000e+06
# max     1.723460e+08  4.516000e+06            1.240500e+07  6.479000e+06
#
#         Team Room /Under Cap  Salary_Cap_Inflated
# count           2.449000e+03         2.449000e+03
# unique                   NaN                  NaN
# top                      NaN                  NaN
# freq                     NaN                  NaN
# mean            5.354990e+06         1.238709e+08
# std             1.115581e+06         3.653293e+06
# min             4.449000e+06         1.187242e+08
# 25%             4.767000e+06         1.214102e+08
# 50%             4.910000e+06         1.236550e+08
# 75%             5.401000e+06         1.249345e+08
# max             7.723000e+06         1.306431e+08
#
# [11 rows x 65 columns]
#
# Preview of Cleaned Dataset:
#     Season           Player        Position   Age Team      TeamID  \
# 0  2018-19     Aaron Gordon         Forward  23.0  ORL  1610612753
# 1  2018-19    Aaron Holiday           Guard  22.0  IND  1610612754
# 2  2018-19      Abdel Nader         Forward  25.0  OKC  1610612760
# 3  2018-19       Al Horford  Center-Forward  33.0  BOS  1610612738
# 4  2018-19  Al-Farouq Aminu         Forward  28.0  POR  1610612757
#
#    Years of Service    GP    GS      MP  ...  Total_Days_Injured  Injury_Risk  \
# 0               4.0  78.0  78.0  2633.0  ...                 5.0     Low Risk
# 1               0.0  50.0   0.0   646.0  ...                 0.0     Low Risk
# 2               2.0  61.0   1.0   694.0  ...                 5.0     Low Risk
# 3              11.0  68.0  68.0  1973.0  ...                28.0    High Risk
# 4               8.0  81.0  81.0  2292.0  ...                 0.0     Low Risk
#
#     Salary Cap   Luxury Tax    1st Apron        BAE  Standard /Non-Taxpayer  \
# 0  101869000.0  123733000.0  129817000.0  3382000.0               8641000.0
# 1  101869000.0  123733000.0  129817000.0  3382000.0               8641000.0
# 2  101869000.0  123733000.0  129817000.0  3382000.0               8641000.0
# 3  101869000.0  123733000.0  129817000.0  3382000.0               8641000.0
# 4  101869000.0  123733000.0  129817000.0  3382000.0               8641000.0
#
#     Taxpayer  Team Room /Under Cap  Salary_Cap_Inflated
# 0  5337000.0             4449000.0         1.187242e+08
# 1  5337000.0             4449000.0         1.187242e+08
# 2  5337000.0             4449000.0         1.187242e+08
# 3  5337000.0             4449000.0         1.187242e+08
# 4  5337000.0             4449000.0         1.187242e+08
#
# [5 rows x 65 columns]
# /tmp/ipykernel_999/4202254248.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba_player_inflated_data_cleaned['TeamID'] = nba_player_inflated_data_cleaned['Team'].map(team_id_mapping)

# %%
# Step 1: Identify potential conflicting contract entries based on (salary, player_name, season)
conflicting_contracts = nba_player_inflated_data_cleaned.groupby(['Player', 'Season', 'Salary']).size().reset_index(name='count')
conflicting_contracts = conflicting_contracts[conflicting_contracts['count'] > 1]

# Step 2: Display conflicting contracts if any are found
if not conflicting_contracts.empty:
    print("Potential Conflicting Contracts Found:")
    print(conflicting_contracts)

# Step 3: Display detailed entries for conflicting contracts
for index, row in conflicting_contracts.iterrows():
    player = row['Player']
    season = row['Season']
    salary = row['Salary']
    print(f"\nDetails of Conflicting Contracts for Player: {player}, Season: {season}, Salary: {salary}")
    print(nba_player_inflated_data_cleaned[(nba_player_inflated_data_cleaned['Player'] == player) & 
                                           (nba_player_inflated_data_cleaned['Season'] == season) & 
                                           (nba_player_inflated_data_cleaned['Salary'] == salary)])

# %%
from neo4j import GraphDatabase
import os
from dotenv import load_dotenv


# Print the current working directory (optional for debugging)
print(os.getcwd())

# Set the path to your .env file relative to the current working directory
dotenv_path = os.path.join(os.getcwd(), '../../.env')
load_dotenv(dotenv_path)

# Neo4j connection parameters from .env
uri = os.getenv("NEO4J_URI")
username = os.getenv("NEO4J_USERNAME")
password = os.getenv("NEO4J_PASSWORD")

# Create a Neo4j driver using the Aura connection details
driver = GraphDatabase.driver(uri, auth=(username, password))
# Out:
# /workspaces/custom_ollama_docker/notebooks/neo4j_data_setup

# %%
# %%writefile graph_database_loader_nba.ipynb
import pandas as pd
from neo4j import GraphDatabase, basic_auth
import numpy as np

# Create a Neo4j driver using the Aura connection details and add connection success check
try:
    driver = GraphDatabase.driver(uri, auth=(username, password))
    driver.verify_connectivity()  # This will check if the connection is successful
    print("Successfully connected to Neo4j!")
except Exception as e:
    print(f"Failed to connect to Neo4j: {e}")

# Rename columns to add '_total' suffix where necessary
nba_player_inflated_data_cleaned = nba_player_inflated_data_cleaned.rename(columns={
    'PTS': 'PTS_total',
    'AST': 'AST_total',
    'TRB': 'TRB_total',
    'STL': 'STL_total',
    'BLK': 'BLK_total',
    'TOV': 'TOV_total',
    'PF': 'PF_total',
    'WS': 'WS_total',
    'OWS': 'OWS_total',
    'DWS': 'DWS_total',
    'VORP': 'VORP_total'
})

# Function to create constraints only if they don't already exist
def create_constraint_if_not_exists(session, constraint_query, constraint_name):
    try:
        check_query = f"SHOW CONSTRAINTS WHERE name = '{constraint_name}'"
        result = session.run(check_query)
        if result.single():
            print(f"Constraint '{constraint_name}' already exists.")
        else:
            session.run(constraint_query)
            print(f"Successfully created constraint: {constraint_name}")
    except Exception as e:
        print(f"Failed to create constraint: {constraint_name}. Error: {e}")


# Function to delete duplicate nodes before creating uniqueness constraints
def delete_duplicate_nodes(session, label, property_name):
    print(f"Deleting duplicate nodes for {label} based on {property_name}...")
    delete_query = f"""
    MATCH (n:{label})
    WITH n.{property_name} AS prop, COLLECT(n) AS nodes
    WHERE SIZE(nodes) > 1
    UNWIND TAIL(nodes) AS duplicateNode
    DETACH DELETE duplicateNode
    """
    session.run(delete_query)
    print(f"Duplicate nodes deleted for {label} based on {property_name}.")


# Setup schema with constraints and cleanup
def setup_schema_with_cleanup(session):
    constraints = [
        {"query": "CREATE CONSTRAINT player_name_unique FOR (p:Player) REQUIRE p.name IS UNIQUE", "name": "player_name_unique"},
        {"query": "CREATE CONSTRAINT team_name_unique FOR (t:Team) REQUIRE t.name IS UNIQUE", "name": "team_name_unique"},
        {"query": "CREATE CONSTRAINT season_name_unique FOR (s:Season) REQUIRE s.name IS UNIQUE", "name": "season_name_unique"},
        {"query": "CREATE CONSTRAINT position_name_unique FOR (pos:Position) REQUIRE pos.name IS UNIQUE", "name": "position_name_unique"},
        # Modify the constraint for Contract nodes to be based on multiple properties
        {"query": "CREATE CONSTRAINT contract_unique FOR (c:Contract) REQUIRE (c.salary, c.player_name, c.season) IS UNIQUE", "name": "contract_unique"},
    ]

    cleanup_mappings = [
        {"label": "Player", "property": "name"},
        {"label": "Team", "property": "name"},
        {"label": "Season", "property": "name"},
        {"label": "Position", "property": "name"},
        {"label": "Contract", "property": "salary"}
    ]

    for mapping in cleanup_mappings:
        delete_duplicate_nodes(session, mapping["label"], mapping["property"])

    for constraint in constraints:
        create_constraint_if_not_exists(session, constraint["query"], constraint["name"])


def create_player_node(tx, player_data):
    query = """
    MERGE (p:Player {name: $name})
    ON CREATE SET p.age = $age,
                  p.position = $position,
                  p.years_of_service = $years_of_service,
                  p.injury_risk = $injury_risk,
                  p.season_salary = $salary,
                  p.season = $season,
                  p.per = $per,
                  p.ws = $ws,
                  p.bpm = $bpm,
                  p.vorp = $vorp
    """
    tx.run(query,
           name=player_data["Player"],
           age=player_data["Age"],
           position=player_data["Position"],
           years_of_service=player_data["Years of Service"],
           injury_risk=player_data["Injury_Risk"],
           salary=player_data["Salary"],
           season=player_data["Season"],
           per=player_data.get("PER"),
           ws=player_data.get("WS"),
           bpm=player_data.get("BPM"),
           vorp=player_data.get("VORP"))


def create_team_node(tx, team_name, team_id, team_data):
    query = """
    MERGE (t:Team {name: $name})
    ON CREATE SET t.team_id = $team_id,
                  t.needs = $needs,
                  t.strategy = $strategy,
                  t.cap_space = $cap_space
    """
    tx.run(query,
           name=team_name,
           team_id=team_id,
           needs=team_data.get("Needs"),
           strategy=team_data.get("Strategy"),
           cap_space=team_data.get("Cap Space"))


def create_season_node(tx, season):
    query = """
    MERGE (s:Season {name: $season})
    """
    tx.run(query, season=season)


def create_position_node(tx, position):
    query = """
    MERGE (pos:Position {name: $position})
    """
    tx.run(query, position=position)


def create_contract_node(tx, contract_data):
    query = """
    MERGE (c:Contract {player_name: $player_name, season: $season})
    ON CREATE SET c.salary = $salary,
                  c.cap = $cap,
                  c.luxury_tax = $luxury_tax,
                  c.duration = $duration,
                  c.player_option = $player_option,
                  c.team_option = $team_option,
                  c.no_trade_clause = $no_trade_clause
    """
    tx.run(query,
           player_name=contract_data["Player"],
           season=contract_data["Season"],
           salary=contract_data["Salary"],
           cap=contract_data["Salary Cap"],
           luxury_tax=contract_data["Luxury Tax"],
           duration=contract_data.get("Contract Duration"),
           player_option=contract_data.get("Player Option"),
           team_option=contract_data.get("Team Option"),
           no_trade_clause=contract_data.get("No Trade Clause"))


def delete_duplicate_contract_nodes(session):
    delete_query = """
    MATCH (c:Contract)
    WITH c.salary AS salary, c.player_name AS player_name, c.season AS season, COLLECT(c) AS contracts
    WHERE SIZE(contracts) > 1
    UNWIND TAIL(contracts) AS duplicateContract
    DETACH DELETE duplicateContract
    """
    session.run(delete_query)
    print("Duplicate Contract nodes deleted based on salary, player_name, and season.")


def create_statistics_node(tx, player_name, stats_data):
    query = """
    MERGE (stat:Statistics {player: $player, season: $season})
    ON CREATE SET 
        stat.ppg = $pts_total,               // Use total fields
        stat.assists_total = $ast_total,
        stat.rebounds_total = $trb_total,
        stat.steals_total = $stl_total,
        stat.blocks_total = $blk_total,
        stat.turnovers_total = $tov_total,
        stat.personal_fouls_total = $pf_total,
        stat.win_shares_total = $ws_total,
        stat.offensive_win_shares_total = $ows_total,
        stat.defensive_win_shares_total = $dws_total,
        stat.vorp_total = $vorp_total,
        stat.games_played = $games_played  // Retain games played without "total" as it isn't cumulative
    """
    tx.run(query, 
           player=player_name, 
           season=stats_data["Season"], 
           pts_total=stats_data["PTS_total"], 
           ast_total=stats_data["AST_total"], 
           trb_total=stats_data["TRB_total"], 
           stl_total=stats_data["STL_total"],
           blk_total=stats_data["BLK_total"],
           tov_total=stats_data["TOV_total"],
           pf_total=stats_data["PF_total"],
           ws_total=stats_data["WS_total"],
           ows_total=stats_data["OWS_total"],
           dws_total=stats_data["DWS_total"],
           vorp_total=stats_data["VORP_total"],
           games_played=stats_data["GP"])




def create_injury_node(tx, player_name, injury_data):
    if pd.isna(injury_data["Total_Days_Injured"]) or pd.isna(injury_data["Injury_Periods"]) or pd.isna(injury_data["Injury_Risk"]):
        return
    query = """
    MERGE (i:Injury {player: $player})
    ON CREATE SET i.total_days = $total_days,
                  i.injury_periods = $injury_periods,
                  i.risk = $risk,
                  i.injury_history = $injury_history
    """
    tx.run(query,
           player=player_name,
           total_days=injury_data["Total_Days_Injured"],
           injury_periods=injury_data["Injury_Periods"],
           risk=injury_data["Injury_Risk"],
           injury_history=injury_data.get("Injury_History"))


def create_relationships(tx, player_data):
    """
    Create relationships between Player, Team, Season, Contract, and other nodes in the database.
    """
    # Player -> Team (Played for Team in a specific season)
    query = """
    MATCH (p:Player {name: $player}), (t:Team {name: $team}), (s:Season {name: $season})
    MERGE (p)-[:HAS_PLAYED_FOR {season: $season}]->(t)
    MERGE (p)-[:PARTICIPATED_IN]->(s)
    """
    tx.run(query, player=player_data["Player"], team=player_data["Team"], season=player_data["Season"])

    # Player -> Contract (Has Contract in a specific season)
    query = """
    MATCH (p:Player {name: $player}), (c:Contract {salary: $salary, season: $season})
    MERGE (p)-[:HAS_CONTRACT {season: $season}]->(c)
    """
    tx.run(query, player=player_data["Player"], salary=player_data["Salary"], season=player_data["Season"])

    # Player -> Statistics (Possesses Statistics in a specific season)
    query = """
    MATCH (p:Player {name: $player}), (stat:Statistics {player: $player, season: $season})
    MERGE (p)-[:POSSESSES {season: $season}]->(stat)
    """
    tx.run(query, player=player_data["Player"], season=player_data["Season"])

    # Player -> Injury (Suffered Injury, if applicable)
    if not pd.isna(player_data["Injured"]) and player_data["Injured"]:
        query = """
        MATCH (p:Player {name: $player}), (i:Injury {player: $player})
        MERGE (p)-[:SUFFERED {season: $season}]->(i)
        """
        tx.run(query, player=player_data["Player"], season=player_data["Season"])

    # Team -> Player (Current roster or traded player)
    query = """
    MATCH (p:Player {name: $player}), (t:Team {name: $team})
    MERGE (t)-[:HAS_PLAYER {season: $season, role: 'Current Roster'}]->(p)
    """
    tx.run(query, player=player_data["Player"], team=player_data["Team"], season=player_data["Season"])

    # Establish relationship for the player's current team
    query = """
    MATCH (p:Player {name: $player}), (t:Team {name: $team})
    MERGE (t)-[:CURRENT_TEAM {season: $season}]->(p)
    """
    tx.run(query, player=player_data["Player"], team=player_data["Team"], season=player_data["Season"])

    print(f"Relationships created for Player: {player_data['Player']} for season: {player_data['Season']}.")


def calculate_and_set_trade_value(tx, player_name):
    # Placeholder for actual calculation logic
    trade_value = 0  # Replace with real calculation if needed
    query = """
    MATCH (p:Player {name: $player})
    SET p.trade_value = $trade_value
    """
    tx.run(query, player=player_name, trade_value=trade_value)


# Example query to check indexes
def check_indexes(session):
    result = session.run("CALL db.indexes")
    for record in result:
        print(record)


def clear_database(session):
    delete_query = "MATCH (n) DETACH DELETE n"
    session.run(delete_query)
    print("All nodes and relationships deleted from the database.")


# Function to clear all constraints and indexes from the database
def clear_constraints_and_indexes(session):
    # Delete all constraints using SHOW CONSTRAINTS
    delete_constraints_query = "SHOW CONSTRAINTS"
    constraints_result = session.run(delete_constraints_query)
    for record in constraints_result:
        constraint_name = record['name']
        drop_constraint_query = f"DROP CONSTRAINT {constraint_name}"
        session.run(drop_constraint_query)
        print(f"Constraint '{constraint_name}' has been deleted.")

    # Delete all indexes using SHOW INDEXES
    delete_indexes_query = "SHOW INDEXES"
    indexes_result = session.run(delete_indexes_query)
    for record in indexes_result:
        index_name = record['name']
        drop_index_query = f"DROP INDEX {index_name}"
        session.run(drop_index_query)
        print(f"Index '{index_name}' has been deleted.")


# Function to create indexes if they don't already exist
def create_index_if_not_exists(session, index_query, index_name):
    try:
        check_query = f"SHOW INDEXES WHERE name = '{index_name}'"
        result = session.run(check_query)
        if result.single():
            print(f"Index '{index_name}' already exists.")
        else:
            session.run(index_query)
            print(f"Successfully created index: {index_name}")
    except Exception as e:
        print(f"Failed to create index: {index_name}. Error: {e}")


# Function to set up indexes
def setup_indexes(session):
    indexes = [
        {"query": "CREATE INDEX player_name_index IF NOT EXISTS FOR (p:Player) ON (p.name)", "name": "player_name_index"},
        {"query": "CREATE INDEX team_name_index IF NOT EXISTS FOR (t:Team) ON (t.name)", "name": "team_name_index"},
        {"query": "CREATE INDEX contract_season_index IF NOT EXISTS FOR (c:Contract) ON (c.season)", "name": "contract_season_index"}
    ]

    for index in indexes:
        create_index_if_not_exists(session, index["query"], index["name"])


# Function to insert data into Neo4j
def insert_enhanced_data(tx, player_data):
    create_player_node(tx, player_data)
    create_team_node(tx, player_data["Team"], player_data["TeamID"], player_data)
    create_season_node(tx, player_data["Season"])
    create_contract_node(tx, player_data)
    create_statistics_node(tx, player_data["Player"], player_data)
    create_injury_node(tx, player_data["Player"], player_data)
    create_relationships(tx, player_data)


# Convert DataFrame to list of dictionaries after renaming
data_dicts = nba_player_inflated_data_cleaned.to_dict(orient='records')

# Continue with the Neo4j insertion code
with driver.session() as session:
    clear_database(session)
    clear_constraints_and_indexes(session)
    setup_schema_with_cleanup(session)
    setup_indexes(session)

    for player_data in data_dicts:
        session.execute_write(insert_enhanced_data, player_data)
        session.execute_write(calculate_and_set_trade_value, player_data["Player"])

print("Data reinserted into a clean Neo4j database with renamed total columns.")
# Out:
# Successfully connected to Neo4j!
# All nodes and relationships deleted from the database.
# Constraint 'contract_unique' has been deleted.
# Constraint 'player_name_unique' has been deleted.
# Constraint 'position_name_unique' has been deleted.
# Constraint 'season_name_unique' has been deleted.
# Constraint 'team_name_unique' has been deleted.
# Index 'contract_season_index' has been deleted.
# Deleting duplicate nodes for Player based on name...
# Duplicate nodes deleted for Player based on name.
# Deleting duplicate nodes for Team based on name...
# Duplicate nodes deleted for Team based on name.
# Deleting duplicate nodes for Season based on name...
# Duplicate nodes deleted for Season based on name.
# Deleting duplicate nodes for Position based on name...
# Duplicate nodes deleted for Position based on name.
# Deleting duplicate nodes for Contract based on salary...
# Duplicate nodes deleted for Contract based on salary.
# Successfully created constraint: player_name_unique
# Successfully created constraint: team_name_unique
# Successfully created constraint: season_name_unique
# Successfully created constraint: position_name_unique
# Successfully created constraint: contract_unique
# Successfully created index: player_name_index
# Successfully created index: team_name_index
# Successfully created index: contract_season_index
# Relationships created for Player: Aaron Gordon for season: 2018-19.
# Relationships created for Player: Aaron Holiday for season: 2018-19.
# Relationships created for Player: Abdel Nader for season: 2018-19.
# Relationships created for Player: Al Horford for season: 2018-19.
# Relationships created for Player: Al-Farouq Aminu for season: 2018-19.
# Relationships created for Player: Alan Williams for season: 2018-19.
# Relationships created for Player: Alec Burks for season: 2018-19.
# Relationships created for Player: Alex Caruso for season: 2018-19.
# Relationships created for Player: Alex Len for season: 2018-19.
# Relationships created for Player: Alex Poythress for season: 2018-19.
# Relationships created for Player: Alfonzo McKinnie for season: 2018-19.
# Relationships created for Player: Alize Johnson for season: 2018-19.
# Relationships created for Player: Allen Crabbe for season: 2018-19.
# Relationships created for Player: Allonzo Trier for season: 2018-19.
# Relationships created for Player: Amir Johnson for season: 2018-19.
# Relationships created for Player: Andre Drummond for season: 2018-19.
# Relationships created for Player: Andre Iguodala for season: 2018-19.
# Relationships created for Player: Andrew Wiggins for season: 2018-19.
# Relationships created for Player: Anfernee Simons for season: 2018-19.
# Relationships created for Player: Anthony Davis for season: 2018-19.
# Relationships created for Player: Anthony Tolliver for season: 2018-19.
# Relationships created for Player: Antonio Blakeney for season: 2018-19.
# Relationships created for Player: Aron Baynes for season: 2018-19.
# Relationships created for Player: Austin Rivers for season: 2018-19.
# Relationships created for Player: Avery Bradley for season: 2018-19.
# Relationships created for Player: BJ Johnson for season: 2018-19.
# Relationships created for Player: Bam Adebayo for season: 2018-19.
# Relationships created for Player: Ben Simmons for season: 2018-19.
# Relationships created for Player: Billy Garrett for season: 2018-19.
# Relationships created for Player: Blake Griffin for season: 2018-19.
# Relationships created for Player: Boban Marjanovic for season: 2018-19.
# Relationships created for Player: Bobby Portis for season: 2018-19.
# Relationships created for Player: Bogdan Bogdanovic for season: 2018-19.
# Relationships created for Player: Bojan Bogdanovic for season: 2018-19.
# Relationships created for Player: Bonzie Colson for season: 2018-19.
# Relationships created for Player: Brad Wanamaker for season: 2018-19.
# Relationships created for Player: Bradley Beal for season: 2018-19.
# Relationships created for Player: Brandon Goodwin for season: 2018-19.
# Relationships created for Player: Brandon Ingram for season: 2018-19.
# Relationships created for Player: Brandon Knight for season: 2018-19.
# Relationships created for Player: Brandon Sampson for season: 2018-19.
# Relationships created for Player: Brook Lopez for season: 2018-19.
# Relationships created for Player: Bruce Brown for season: 2018-19.
# Relationships created for Player: Bruno Caboclo for season: 2018-19.
# Relationships created for Player: Bryn Forbes for season: 2018-19.
# Relationships created for Player: Buddy Hield for season: 2018-19.
# Relationships created for Player: CJ McCollum for season: 2018-19.
# Relationships created for Player: Caleb Swanigan for season: 2018-19.
# Relationships created for Player: Cam Reynolds for season: 2018-19.
# Relationships created for Player: Caris LeVert for season: 2018-19.
# Relationships created for Player: Cedi Osman for season: 2018-19.
# Relationships created for Player: Chandler Hutchison for season: 2018-19.
# Relationships created for Player: Chandler Parsons for season: 2018-19.
# Relationships created for Player: Channing Frye for season: 2018-19.
# Relationships created for Player: Chasson Randle for season: 2018-19.
# Relationships created for Player: Cheick Diallo for season: 2018-19.
# Relationships created for Player: Chimezie Metu for season: 2018-19.
# Relationships created for Player: Chris Boucher for season: 2018-19.
# Relationships created for Player: Chris Paul for season: 2018-19.
# Relationships created for Player: Christian Wood for season: 2018-19.
# Relationships created for Player: Cody Zeller for season: 2018-19.
# Relationships created for Player: Collin Sexton for season: 2018-19.
# Relationships created for Player: Corey Brewer for season: 2018-19.
# Relationships created for Player: Cory Joseph for season: 2018-19.
# Relationships created for Player: Courtney Lee for season: 2018-19.
# Relationships created for Player: Cristiano Felicio for season: 2018-19.
# Relationships created for Player: D'Angelo Russell for season: 2018-19.
# Relationships created for Player: Damian Lillard for season: 2018-19.
# Relationships created for Player: Damion Lee for season: 2018-19.
# Relationships created for Player: Damyean Dotson for season: 2018-19.
# Relationships created for Player: Daniel Theis for season: 2018-19.
# Relationships created for Player: Danilo Gallinari for season: 2018-19.
# Relationships created for Player: Danny Green for season: 2018-19.
# Relationships created for Player: Dante Cunningham for season: 2018-19.
# Relationships created for Player: Dante Exum for season: 2018-19.
# Relationships created for Player: Dario Saric for season: 2018-19.
# Relationships created for Player: Darius Miller for season: 2018-19.
# Relationships created for Player: Darren Collison for season: 2018-19.
# Relationships created for Player: Daryl Macon for season: 2018-19.
# Relationships created for Player: David Nwaba for season: 2018-19.
# Relationships created for Player: Davis Bertans for season: 2018-19.
# Relationships created for Player: De'Aaron Fox for season: 2018-19.
# Relationships created for Player: De'Anthony Melton for season: 2018-19.
# Relationships created for Player: DeMar DeRozan for season: 2018-19.
# Relationships created for Player: DeMarcus Cousins for season: 2018-19.
# Relationships created for Player: DeMarre Carroll for season: 2018-19.
# Relationships created for Player: Deandre Ayton for season: 2018-19.
# Relationships created for Player: Delon Wright for season: 2018-19.
# Relationships created for Player: Deng Adel for season: 2018-19.
# Relationships created for Player: Deonte Burton for season: 2018-19.
# Relationships created for Player: Derrick Favors for season: 2018-19.
# Relationships created for Player: Derrick Rose for season: 2018-19.
# Relationships created for Player: Derrick White for season: 2018-19.
# Relationships created for Player: Devin Booker for season: 2018-19.
# Relationships created for Player: Devin Harris for season: 2018-19.
# Relationships created for Player: Devin Robinson for season: 2018-19.
# Relationships created for Player: Dewayne Dedmon for season: 2018-19.
# Relationships created for Player: Dillon Brooks for season: 2018-19.
# Relationships created for Player: Dion Waiters for season: 2018-19.
# Relationships created for Player: Dirk Nowitzki for season: 2018-19.
# Relationships created for Player: Domantas Sabonis for season: 2018-19.
# Relationships created for Player: Donovan Mitchell for season: 2018-19.
# Relationships created for Player: Donte DiVincenzo for season: 2018-19.
# Relationships created for Player: Dorian Finney-Smith for season: 2018-19.
# Relationships created for Player: Doug McDermott for season: 2018-19.
# Relationships created for Player: Dragan Bender for season: 2018-19.
# Relationships created for Player: Draymond Green for season: 2018-19.
# Relationships created for Player: Duncan Robinson for season: 2018-19.
# Relationships created for Player: Dwayne Bacon for season: 2018-19.
# Relationships created for Player: Dwight Powell for season: 2018-19.
# Relationships created for Player: Dwyane Wade for season: 2018-19.
# Relationships created for Player: Dzanan Musa for season: 2018-19.
# Relationships created for Player: E'Twaun Moore for season: 2018-19.
# Relationships created for Player: Ed Davis for season: 2018-19.
# Relationships created for Player: Edmond Sumner for season: 2018-19.
# Relationships created for Player: Elfrid Payton for season: 2018-19.
# Relationships created for Player: Elie Okobo for season: 2018-19.
# Relationships created for Player: Emmanuel Mudiay for season: 2018-19.
# Relationships created for Player: Eric Bledsoe for season: 2018-19.
# Relationships created for Player: Eric Gordon for season: 2018-19.
# Relationships created for Player: Ersan Ilyasova for season: 2018-19.
# Relationships created for Player: Evan Fournier for season: 2018-19.
# Relationships created for Player: Evan Turner for season: 2018-19.
# Relationships created for Player: Frank Jackson for season: 2018-19.
# Relationships created for Player: Frank Kaminsky for season: 2018-19.
# Relationships created for Player: Frank Ntilikina for season: 2018-19.
# Relationships created for Player: Fred VanVleet for season: 2018-19.
# Relationships created for Player: Furkan Korkmaz for season: 2018-19.
# Relationships created for Player: Garrett Temple for season: 2018-19.
# Relationships created for Player: Gary Clark for season: 2018-19.
# Relationships created for Player: Gary Harris for season: 2018-19.
# Relationships created for Player: George Hill for season: 2018-19.
# Relationships created for Player: Georges Niang for season: 2018-19.
# Relationships created for Player: Gerald Green for season: 2018-19.
# Relationships created for Player: Giannis Antetokounmpo for season: 2018-19.
# Relationships created for Player: Glenn Robinson III for season: 2018-19.
# Relationships created for Player: Goran Dragic for season: 2018-19.
# Relationships created for Player: Gordon Hayward for season: 2018-19.
# Relationships created for Player: Gorgui Dieng for season: 2018-19.
# Relationships created for Player: Grayson Allen for season: 2018-19.
# Relationships created for Player: Greg Monroe for season: 2018-19.
# Relationships created for Player: Guerschon Yabusele for season: 2018-19.
# Relationships created for Player: Hamidou Diallo for season: 2018-19.
# Relationships created for Player: Harrison Barnes for season: 2018-19.
# Relationships created for Player: Hassan Whiteside for season: 2018-19.
# Relationships created for Player: Haywood Highsmith for season: 2018-19.
# Relationships created for Player: Henry Ellenson for season: 2018-19.
# Relationships created for Player: Ian Clark for season: 2018-19.
# Relationships created for Player: Ian Mahinmi for season: 2018-19.
# Relationships created for Player: Iman Shumpert for season: 2018-19.
# Relationships created for Player: Isaac Bonga for season: 2018-19.
# Relationships created for Player: Isaiah Hartenstein for season: 2018-19.
# Relationships created for Player: Isaiah Thomas for season: 2018-19.
# Relationships created for Player: Ivan Rabb for season: 2018-19.
# Relationships created for Player: JR Smith for season: 2018-19.
# Relationships created for Player: JaMychal Green for season: 2018-19.
# Relationships created for Player: JaVale McGee for season: 2018-19.
# Relationships created for Player: Jabari Parker for season: 2018-19.
# Relationships created for Player: Jacob Evans for season: 2018-19.
# Relationships created for Player: Jae Crowder for season: 2018-19.
# Relationships created for Player: Jahlil Okafor for season: 2018-19.
# Relationships created for Player: Jake Layman for season: 2018-19.
# Relationships created for Player: Jalen Brunson for season: 2018-19.
# Relationships created for Player: Jamal Crawford for season: 2018-19.
# Relationships created for Player: Jamal Murray for season: 2018-19.
# Relationships created for Player: James Harden for season: 2018-19.
# Relationships created for Player: James Johnson for season: 2018-19.
# Relationships created for Player: Jared Dudley for season: 2018-19.
# Relationships created for Player: Jared Terrell for season: 2018-19.
# Relationships created for Player: Jarell Martin for season: 2018-19.
# Relationships created for Player: Jaron Blossomgame for season: 2018-19.
# Relationships created for Player: Jarred Vanderbilt for season: 2018-19.
# Relationships created for Player: Jarrett Allen for season: 2018-19.
# Relationships created for Player: Jaylen Adams for season: 2018-19.
# Relationships created for Player: Jaylen Brown for season: 2018-19.
# Relationships created for Player: Jayson Tatum for season: 2018-19.
# Relationships created for Player: Jeff Green for season: 2018-19.
# Relationships created for Player: Jeff Teague for season: 2018-19.
# Relationships created for Player: Jemerrio Jones for season: 2018-19.
# Relationships created for Player: Jerami Grant for season: 2018-19.
# Relationships created for Player: Jeremy Lamb for season: 2018-19.
# Relationships created for Player: Jeremy Lin for season: 2018-19.
# Relationships created for Player: Jerian Grant for season: 2018-19.
# Relationships created for Player: Jerome Robinson for season: 2018-19.
# Relationships created for Player: Jerryd Bayless for season: 2018-19.
# Relationships created for Player: Jevon Carter for season: 2018-19.
# Relationships created for Player: Jimmer Fredette for season: 2018-19.
# Relationships created for Player: Jimmy Butler for season: 2018-19.
# Relationships created for Player: Joakim Noah for season: 2018-19.
# Relationships created for Player: Jodie Meeks for season: 2018-19.
# Relationships created for Player: Joe Harris for season: 2018-19.
# Relationships created for Player: Joe Ingles for season: 2018-19.
# Relationships created for Player: Joel Embiid for season: 2018-19.
# Relationships created for Player: John Collins for season: 2018-19.
# Relationships created for Player: John Henson for season: 2018-19.
# Relationships created for Player: Johnathan Motley for season: 2018-19.
# Relationships created for Player: Johnathan Williams for season: 2018-19.
# Relationships created for Player: Jon Leuer for season: 2018-19.
# Relationships created for Player: Jonah Bolden for season: 2018-19.
# Relationships created for Player: Jonas Jerebko for season: 2018-19.
# Relationships created for Player: Jonas Valanciunas for season: 2018-19.
# Relationships created for Player: Jonathan Isaac for season: 2018-19.
# Relationships created for Player: Jonathon Simmons for season: 2018-19.
# Relationships created for Player: Jordan Bell for season: 2018-19.
# Relationships created for Player: Jordan Clarkson for season: 2018-19.
# Relationships created for Player: Jordan Loyd for season: 2018-19.
# Relationships created for Player: Jordan McRae for season: 2018-19.
# Relationships created for Player: Jose Calderon for season: 2018-19.
# Relationships created for Player: Josh Hart for season: 2018-19.
# Relationships created for Player: Josh Jackson for season: 2018-19.
# Relationships created for Player: Josh Okogie for season: 2018-19.
# Relationships created for Player: Josh Richardson for season: 2018-19.
# Relationships created for Player: Jrue Holiday for season: 2018-19.
# Relationships created for Player: Julian Washburn for season: 2018-19.
# Relationships created for Player: Julius Randle for season: 2018-19.
# Relationships created for Player: Justin Anderson for season: 2018-19.
# Relationships created for Player: Justin Holiday for season: 2018-19.
# Relationships created for Player: Justin Jackson for season: 2018-19.
# Relationships created for Player: Justise Winslow for season: 2018-19.
# Relationships created for Player: Jusuf Nurkic for season: 2018-19.
# Relationships created for Player: Kadeem Allen for season: 2018-19.
# Relationships created for Player: Karl-Anthony Towns for season: 2018-19.
# Relationships created for Player: Kawhi Leonard for season: 2018-19.
# Relationships created for Player: Keita Bates-Diop for season: 2018-19.
# Relationships created for Player: Kelly Olynyk for season: 2018-19.
# Relationships created for Player: Kemba Walker for season: 2018-19.
# Relationships created for Player: Kenneth Faried for season: 2018-19.
# Relationships created for Player: Kenrich Williams for season: 2018-19.
# Relationships created for Player: Kent Bazemore for season: 2018-19.
# Relationships created for Player: Kentavious Caldwell-Pope for season: 2018-19.
# Relationships created for Player: Kevin Durant for season: 2018-19.
# Relationships created for Player: Kevin Huerter for season: 2018-19.
# Relationships created for Player: Kevin Love for season: 2018-19.
# Relationships created for Player: Kevon Looney for season: 2018-19.
# Relationships created for Player: Khem Birch for season: 2018-19.
# Relationships created for Player: Khris Middleton for season: 2018-19.
# Relationships created for Player: Khyri Thomas for season: 2018-19.
# Relationships created for Player: Klay Thompson for season: 2018-19.
# Relationships created for Player: Kris Dunn for season: 2018-19.
# Relationships created for Player: Kyle Anderson for season: 2018-19.
# Relationships created for Player: Kyle Korver for season: 2018-19.
# Relationships created for Player: Kyle Kuzma for season: 2018-19.
# Relationships created for Player: Kyle Lowry for season: 2018-19.
# Relationships created for Player: Kyle O'Quinn for season: 2018-19.
# Relationships created for Player: Kyrie Irving for season: 2018-19.
# Relationships created for Player: LaMarcus Aldridge for season: 2018-19.
# Relationships created for Player: Lance Stephenson for season: 2018-19.
# Relationships created for Player: Lance Thomas for season: 2018-19.
# Relationships created for Player: Landry Shamet for season: 2018-19.
# Relationships created for Player: Langston Galloway for season: 2018-19.
# Relationships created for Player: Lauri Markkanen for season: 2018-19.
# Relationships created for Player: LeBron James for season: 2018-19.
# Relationships created for Player: Lonzo Ball for season: 2018-19.
# Relationships created for Player: Luka Doncic for season: 2018-19.
# Relationships created for Player: Luke Kennard for season: 2018-19.
# Relationships created for Player: Luke Kornet for season: 2018-19.
# Relationships created for Player: Luol Deng for season: 2018-19.
# Relationships created for Player: Malcolm Brogdon for season: 2018-19.
# Relationships created for Player: Malcolm Miller for season: 2018-19.
# Relationships created for Player: Malik Beasley for season: 2018-19.
# Relationships created for Player: Malik Monk for season: 2018-19.
# Relationships created for Player: Marc Gasol for season: 2018-19.
# Relationships created for Player: Marco Belinelli for season: 2018-19.
# Relationships created for Player: Marcus Derrickson for season: 2018-19.
# Relationships created for Player: Marcus Smart for season: 2018-19.
# Relationships created for Player: Mario Hezonja for season: 2018-19.
# Relationships created for Player: Markelle Fultz for season: 2018-19.
# Relationships created for Player: Markieff Morris for season: 2018-19.
# Relationships created for Player: Marquese Chriss for season: 2018-19.
# Relationships created for Player: Marvin Williams for season: 2018-19.
# Relationships created for Player: Mason Plumlee for season: 2018-19.
# Relationships created for Player: Matthew Dellavedova for season: 2018-19.
# Relationships created for Player: Maxi Kleber for season: 2018-19.
# Relationships created for Player: Meyers Leonard for season: 2018-19.
# Relationships created for Player: Michael Carter-Williams for season: 2018-19.
# Relationships created for Player: Michael Kidd-Gilchrist for season: 2018-19.
# Relationships created for Player: Mikal Bridges for season: 2018-19.
# Relationships created for Player: Mike Conley for season: 2018-19.
# Relationships created for Player: Mike Muscala for season: 2018-19.
# Relationships created for Player: Mike Scott for season: 2018-19.
# Relationships created for Player: Miles Bridges for season: 2018-19.
# Relationships created for Player: Mitchell Creek for season: 2018-19.
# Relationships created for Player: Mo Bamba for season: 2018-19.
# Relationships created for Player: Monte Morris for season: 2018-19.
# Relationships created for Player: Montrezl Harrell for season: 2018-19.
# Relationships created for Player: Moritz Wagner for season: 2018-19.
# Relationships created for Player: Myles Turner for season: 2018-19.
# Relationships created for Player: Nemanja Bjelica for season: 2018-19.
# Relationships created for Player: Nicolas Batum for season: 2018-19.
# Relationships created for Player: Nik Stauskas for season: 2018-19.
# Relationships created for Player: Nikola Jokic for season: 2018-19.
# Relationships created for Player: Nikola Mirotic for season: 2018-19.
# Relationships created for Player: Nikola Vucevic for season: 2018-19.
# Relationships created for Player: Noah Vonleh for season: 2018-19.
# Relationships created for Player: Norman Powell for season: 2018-19.
# Relationships created for Player: OG Anunoby for season: 2018-19.
# Relationships created for Player: Omari Spellman for season: 2018-19.
# Relationships created for Player: PJ Dozier for season: 2018-19.
# Relationships created for Player: Pascal Siakam for season: 2018-19.
# Relationships created for Player: Pat Connaughton for season: 2018-19.
# Relationships created for Player: Patrick Beverley for season: 2018-19.
# Relationships created for Player: Patrick Patterson for season: 2018-19.
# Relationships created for Player: Pau Gasol for season: 2018-19.
# Relationships created for Player: Paul George for season: 2018-19.
# Relationships created for Player: Paul Millsap for season: 2018-19.
# Relationships created for Player: Quincy Pondexter for season: 2018-19.
# Relationships created for Player: Quinn Cook for season: 2018-19.
# Relationships created for Player: RJ Hunter for season: 2018-19.
# Relationships created for Player: Rajon Rondo for season: 2018-19.
# Relationships created for Player: Raul Neto for season: 2018-19.
# Relationships created for Player: Rawle Alkins for season: 2018-19.
# Relationships created for Player: Raymond Felton for season: 2018-19.
# Relationships created for Player: Reggie Jackson for season: 2018-19.
# Relationships created for Player: Ricky Rubio for season: 2018-19.
# Relationships created for Player: Robert Covington for season: 2018-19.
# Relationships created for Player: Robin Lopez for season: 2018-19.
# Relationships created for Player: Rodions Kurucs for season: 2018-19.
# Relationships created for Player: Rodney Hood for season: 2018-19.
# Relationships created for Player: Rodney McGruder for season: 2018-19.
# Relationships created for Player: Rondae Hollis-Jefferson for season: 2018-19.
# Relationships created for Player: Royce O'Neale for season: 2018-19.
# Relationships created for Player: Rudy Gay for season: 2018-19.
# Relationships created for Player: Russell Westbrook for season: 2018-19.
# Relationships created for Player: Ryan Anderson for season: 2018-19.
# Relationships created for Player: Ryan Arcidiacono for season: 2018-19.
# Relationships created for Player: Ryan Broekhoff for season: 2018-19.
# Relationships created for Player: Salah Mejri for season: 2018-19.
# Relationships created for Player: Sam Dekker for season: 2018-19.
# Relationships created for Player: Semi Ojeleye for season: 2018-19.
# Relationships created for Player: Serge Ibaka for season: 2018-19.
# Relationships created for Player: Seth Curry for season: 2018-19.
# Relationships created for Player: Shabazz Napier for season: 2018-19.
# Relationships created for Player: Shai Gilgeous-Alexander for season: 2018-19.
# Relationships created for Player: Shake Milton for season: 2018-19.
# Relationships created for Player: Shaquille Harrison for season: 2018-19.
# Relationships created for Player: Shaun Livingston for season: 2018-19.
# Relationships created for Player: Shelvin Mack for season: 2018-19.
# Relationships created for Player: Sindarius Thornwell for season: 2018-19.
# Relationships created for Player: Skal Labissiere for season: 2018-19.
# Relationships created for Player: Solomon Hill for season: 2018-19.
# Relationships created for Player: Spencer Dinwiddie for season: 2018-19.
# Relationships created for Player: Stanley Johnson for season: 2018-19.
# Relationships created for Player: Stephen Curry for season: 2018-19.
# Relationships created for Player: Sterling Brown for season: 2018-19.
# Relationships created for Player: Steven Adams for season: 2018-19.
# Relationships created for Player: Taj Gibson for season: 2018-19.
# Relationships created for Player: Taurean Prince for season: 2018-19.
# Relationships created for Player: Terrance Ferguson for season: 2018-19.
# Relationships created for Player: Terrence Ross for season: 2018-19.
# Relationships created for Player: Terry Rozier for season: 2018-19.
# Relationships created for Player: Thabo Sefolosha for season: 2018-19.
# Relationships created for Player: Thaddeus Young for season: 2018-19.
# Relationships created for Player: Theo Pinson for season: 2018-19.
# Relationships created for Player: Thomas Bryant for season: 2018-19.
# Relationships created for Player: Thomas Welsh for season: 2018-19.
# Relationships created for Player: Thon Maker for season: 2018-19.
# Relationships created for Player: Tim Frazier for season: 2018-19.
# Relationships created for Player: Tobias Harris for season: 2018-19.
# Relationships created for Player: Tomas Satoransky for season: 2018-19.
# Relationships created for Player: Tony Parker for season: 2018-19.
# Relationships created for Player: Tony Snell for season: 2018-19.
# Relationships created for Player: Torrey Craig for season: 2018-19.
# Relationships created for Player: Trae Young for season: 2018-19.
# Relationships created for Player: Treveon Graham for season: 2018-19.
# Relationships created for Player: Trevor Ariza for season: 2018-19.
# Relationships created for Player: Trey Burke for season: 2018-19.
# Relationships created for Player: Trey Lyles for season: 2018-19.
# Relationships created for Player: Troy Daniels for season: 2018-19.
# Relationships created for Player: Troy Williams for season: 2018-19.
# Relationships created for Player: Tyler Cavanaugh for season: 2018-19.
# Relationships created for Player: Tyler Dorsey for season: 2018-19.
# Relationships created for Player: Tyler Johnson for season: 2018-19.
# Relationships created for Player: Tyler Lydon for season: 2018-19.
# Relationships created for Player: Tyrone Wallace for season: 2018-19.
# Relationships created for Player: Tyus Jones for season: 2018-19.
# Relationships created for Player: Udonis Haslem for season: 2018-19.
# Relationships created for Player: Victor Oladipo for season: 2018-19.
# Relationships created for Player: Vince Carter for season: 2018-19.
# Relationships created for Player: Wayne Ellington for season: 2018-19.
# Relationships created for Player: Wayne Selden for season: 2018-19.
# Relationships created for Player: Wesley Johnson for season: 2018-19.
# Relationships created for Player: Wesley Matthews for season: 2018-19.
# Relationships created for Player: Will Barton for season: 2018-19.
# Relationships created for Player: Willie Cauley-Stein for season: 2018-19.
# Relationships created for Player: Willy Hernangomez for season: 2018-19.
# Relationships created for Player: Wilson Chandler for season: 2018-19.
# Relationships created for Player: Yogi Ferrell for season: 2018-19.
# Relationships created for Player: Yuta Watanabe for season: 2018-19.
# Relationships created for Player: Zach Collins for season: 2018-19.
# Relationships created for Player: Zach LaVine for season: 2018-19.
# Relationships created for Player: Zaza Pachulia for season: 2018-19.
# Relationships created for Player: Zhaire Smith for season: 2018-19.
# Relationships created for Player: Aaron Gordon for season: 2019-20.
# Relationships created for Player: Aaron Holiday for season: 2019-20.
# Relationships created for Player: Abdel Nader for season: 2019-20.
# Relationships created for Player: Adam Mokoka for season: 2019-20.
# Relationships created for Player: Admiral Schofield for season: 2019-20.
# Relationships created for Player: Al Horford for season: 2019-20.
# Relationships created for Player: Al-Farouq Aminu for season: 2019-20.
# Relationships created for Player: Alec Burks for season: 2019-20.
# Relationships created for Player: Alen Smailagic for season: 2019-20.
# Relationships created for Player: Alex Caruso for season: 2019-20.
# Relationships created for Player: Alex Len for season: 2019-20.
# Relationships created for Player: Alfonzo McKinnie for season: 2019-20.
# Relationships created for Player: Alize Johnson for season: 2019-20.
# Relationships created for Player: Amir Coffey for season: 2019-20.
# Relationships created for Player: Andre Drummond for season: 2019-20.
# Relationships created for Player: Andre Iguodala for season: 2019-20.
# Relationships created for Player: Andre Roberson for season: 2019-20.
# Relationships created for Player: Andrew Wiggins for season: 2019-20.
# Relationships created for Player: Anfernee Simons for season: 2019-20.
# Relationships created for Player: Anthony Davis for season: 2019-20.
# Relationships created for Player: Anthony Tolliver for season: 2019-20.
# Relationships created for Player: Antonius Cleveland for season: 2019-20.
# Relationships created for Player: Anzejs Pasecniks for season: 2019-20.
# Relationships created for Player: Aron Baynes for season: 2019-20.
# Relationships created for Player: Austin Rivers for season: 2019-20.
# Relationships created for Player: Avery Bradley for season: 2019-20.
# Relationships created for Player: BJ Johnson for season: 2019-20.
# Relationships created for Player: Bam Adebayo for season: 2019-20.
# Relationships created for Player: Ben McLemore for season: 2019-20.
# Relationships created for Player: Ben Simmons for season: 2019-20.
# Relationships created for Player: Blake Griffin for season: 2019-20.
# Relationships created for Player: Boban Marjanovic for season: 2019-20.
# Relationships created for Player: Bobby Portis for season: 2019-20.
# Relationships created for Player: Bogdan Bogdanovic for season: 2019-20.
# Relationships created for Player: Bojan Bogdanovic for season: 2019-20.
# Relationships created for Player: Brad Wanamaker for season: 2019-20.
# Relationships created for Player: Bradley Beal for season: 2019-20.
# Relationships created for Player: Brandon Clarke for season: 2019-20.
# Relationships created for Player: Brandon Goodwin for season: 2019-20.
# Relationships created for Player: Brandon Ingram for season: 2019-20.
# Relationships created for Player: Brandon Knight for season: 2019-20.
# Relationships created for Player: Brook Lopez for season: 2019-20.
# Relationships created for Player: Bruce Brown for season: 2019-20.
# Relationships created for Player: Bruno Caboclo for season: 2019-20.
# Relationships created for Player: Bruno Fernando for season: 2019-20.
# Relationships created for Player: Bryn Forbes for season: 2019-20.
# Relationships created for Player: Buddy Hield for season: 2019-20.
# Relationships created for Player: CJ McCollum for season: 2019-20.
# Relationships created for Player: Caleb Martin for season: 2019-20.
# Relationships created for Player: Cam Reddish for season: 2019-20.
# Relationships created for Player: Cameron Johnson for season: 2019-20.
# Relationships created for Player: Cameron Payne for season: 2019-20.
# Relationships created for Player: Caris LeVert for season: 2019-20.
# Relationships created for Player: Carmelo Anthony for season: 2019-20.
# Relationships created for Player: Carsen Edwards for season: 2019-20.
# Relationships created for Player: Cedi Osman for season: 2019-20.
# Relationships created for Player: Chandler Hutchison for season: 2019-20.
# Relationships created for Player: Cheick Diallo for season: 2019-20.
# Relationships created for Player: Chimezie Metu for season: 2019-20.
# Relationships created for Player: Chris Boucher for season: 2019-20.
# Relationships created for Player: Chris Clemons for season: 2019-20.
# Relationships created for Player: Chris Paul for season: 2019-20.
# Relationships created for Player: Chris Silva for season: 2019-20.
# Relationships created for Player: Christian Wood for season: 2019-20.
# Relationships created for Player: Coby White for season: 2019-20.
# Relationships created for Player: Cody Martin for season: 2019-20.
# Relationships created for Player: Cody Zeller for season: 2019-20.
# Relationships created for Player: Collin Sexton for season: 2019-20.
# Relationships created for Player: Corey Brewer for season: 2019-20.
# Relationships created for Player: Cory Joseph for season: 2019-20.
# Relationships created for Player: Courtney Lee for season: 2019-20.
# Relationships created for Player: Cristiano Felicio for season: 2019-20.
# Relationships created for Player: D'Angelo Russell for season: 2019-20.
# Relationships created for Player: DaQuan Jeffries for season: 2019-20.
# Relationships created for Player: Damian Jones for season: 2019-20.
# Relationships created for Player: Damian Lillard for season: 2019-20.
# Relationships created for Player: Damion Lee for season: 2019-20.
# Relationships created for Player: Damyean Dotson for season: 2019-20.
# Relationships created for Player: Daniel Theis for season: 2019-20.
# Relationships created for Player: Danilo Gallinari for season: 2019-20.
# Relationships created for Player: Danny Green for season: 2019-20.
# Relationships created for Player: Dante Exum for season: 2019-20.
# Relationships created for Player: Dario Saric for season: 2019-20.
# Relationships created for Player: Darius Bazley for season: 2019-20.
# Relationships created for Player: Darius Garland for season: 2019-20.
# Relationships created for Player: David Nwaba for season: 2019-20.
# Relationships created for Player: Davis Bertans for season: 2019-20.
# Relationships created for Player: De'Aaron Fox for season: 2019-20.
# Relationships created for Player: De'Andre Hunter for season: 2019-20.
# Relationships created for Player: De'Anthony Melton for season: 2019-20.
# Relationships created for Player: DeMar DeRozan for season: 2019-20.
# Relationships created for Player: DeMarre Carroll for season: 2019-20.
# Relationships created for Player: Dean Wade for season: 2019-20.
# Relationships created for Player: Deandre Ayton for season: 2019-20.
# Relationships created for Player: Dejounte Murray for season: 2019-20.
# Relationships created for Player: Delon Wright for season: 2019-20.
# Relationships created for Player: Denzel Valentine for season: 2019-20.
# Relationships created for Player: Deonte Burton for season: 2019-20.
# Relationships created for Player: Derrick Favors for season: 2019-20.
# Relationships created for Player: Derrick Rose for season: 2019-20.
# Relationships created for Player: Derrick White for season: 2019-20.
# Relationships created for Player: Devin Booker for season: 2019-20.
# Relationships created for Player: Dewan Hernandez for season: 2019-20.
# Relationships created for Player: Dewayne Dedmon for season: 2019-20.
# Relationships created for Player: Dillon Brooks for season: 2019-20.
# Relationships created for Player: Dion Waiters for season: 2019-20.
# Relationships created for Player: Domantas Sabonis for season: 2019-20.
# Relationships created for Player: Donovan Mitchell for season: 2019-20.
# Relationships created for Player: Donte DiVincenzo for season: 2019-20.
# Relationships created for Player: Dorian Finney-Smith for season: 2019-20.
# Relationships created for Player: Doug McDermott for season: 2019-20.
# Relationships created for Player: Draymond Green for season: 2019-20.
# Relationships created for Player: Drew Eubanks for season: 2019-20.
# Relationships created for Player: Duncan Robinson for season: 2019-20.
# Relationships created for Player: Dwayne Bacon for season: 2019-20.
# Relationships created for Player: Dwight Howard for season: 2019-20.
# Relationships created for Player: Dwight Powell for season: 2019-20.
# Relationships created for Player: Dzanan Musa for season: 2019-20.
# Relationships created for Player: E'Twaun Moore for season: 2019-20.
# Relationships created for Player: Edmond Sumner for season: 2019-20.
# Relationships created for Player: Elfrid Payton for season: 2019-20.
# Relationships created for Player: Elie Okobo for season: 2019-20.
# Relationships created for Player: Emmanuel Mudiay for season: 2019-20.
# Relationships created for Player: Eric Bledsoe for season: 2019-20.
# Relationships created for Player: Eric Gordon for season: 2019-20.
# Relationships created for Player: Eric Paschall for season: 2019-20.
# Relationships created for Player: Ersan Ilyasova for season: 2019-20.
# Relationships created for Player: Evan Fournier for season: 2019-20.
# Relationships created for Player: Evan Turner for season: 2019-20.
# Relationships created for Player: Frank Jackson for season: 2019-20.
# Relationships created for Player: Frank Kaminsky for season: 2019-20.
# Relationships created for Player: Frank Ntilikina for season: 2019-20.
# Relationships created for Player: Fred VanVleet for season: 2019-20.
# Relationships created for Player: Furkan Korkmaz for season: 2019-20.
# Relationships created for Player: Garrett Temple for season: 2019-20.
# Relationships created for Player: Garrison Mathews for season: 2019-20.
# Relationships created for Player: Gary Clark for season: 2019-20.
# Relationships created for Player: Gary Harris for season: 2019-20.
# Relationships created for Player: Gary Payton II for season: 2019-20.
# Relationships created for Player: George Hill for season: 2019-20.
# Relationships created for Player: Georges Niang for season: 2019-20.
# Relationships created for Player: Giannis Antetokounmpo for season: 2019-20.
# Relationships created for Player: Glenn Robinson III for season: 2019-20.
# Relationships created for Player: Goga Bitadze for season: 2019-20.
# Relationships created for Player: Goran Dragic for season: 2019-20.
# Relationships created for Player: Gordon Hayward for season: 2019-20.
# Relationships created for Player: Gorgui Dieng for season: 2019-20.
# Relationships created for Player: Grant Williams for season: 2019-20.
# Relationships created for Player: Grayson Allen for season: 2019-20.
# Relationships created for Player: Hamidou Diallo for season: 2019-20.
# Relationships created for Player: Harrison Barnes for season: 2019-20.
# Relationships created for Player: Hassan Whiteside for season: 2019-20.
# Relationships created for Player: Ian Mahinmi for season: 2019-20.
# Relationships created for Player: Ignas Brazdeikis for season: 2019-20.
# Relationships created for Player: Isaac Bonga for season: 2019-20.
# Relationships created for Player: Ivica Zubac for season: 2019-20.
# Relationships created for Player: JR Smith for season: 2019-20.
# Relationships created for Player: Ja Morant for season: 2019-20.
# Relationships created for Player: JaKarr Sampson for season: 2019-20.
# Relationships created for Player: JaMychal Green for season: 2019-20.
# Relationships created for Player: JaVale McGee for season: 2019-20.
# Relationships created for Player: Jabari Parker for season: 2019-20.
# Relationships created for Player: Jacob Evans for season: 2019-20.
# Relationships created for Player: Jae Crowder for season: 2019-20.
# Relationships created for Player: Jahlil Okafor for season: 2019-20.
# Relationships created for Player: Jake Layman for season: 2019-20.
# Relationships created for Player: Jalen Brunson for season: 2019-20.
# Relationships created for Player: Jalen Lecque for season: 2019-20.
# Relationships created for Player: Jalen McDaniels for season: 2019-20.
# Relationships created for Player: Jamal Murray for season: 2019-20.
# Relationships created for Player: James Harden for season: 2019-20.
# Relationships created for Player: James Johnson for season: 2019-20.
# Relationships created for Player: Jared Dudley for season: 2019-20.
# Relationships created for Player: Jarrell Brantley for season: 2019-20.
# Relationships created for Player: Jarrett Allen for season: 2019-20.
# Relationships created for Player: Jarrett Culver for season: 2019-20.
# Relationships created for Player: Javonte Green for season: 2019-20.
# Relationships created for Player: Jaxson Hayes for season: 2019-20.
# Relationships created for Player: Jaylen Brown for season: 2019-20.
# Relationships created for Player: Jaylen Hoard for season: 2019-20.
# Relationships created for Player: Jaylen Nowell for season: 2019-20.
# Relationships created for Player: Jayson Tatum for season: 2019-20.
# Relationships created for Player: Jeff Green for season: 2019-20.
# Relationships created for Player: Jeff Teague for season: 2019-20.
# Relationships created for Player: Jerami Grant for season: 2019-20.
# Relationships created for Player: Jeremiah Martin for season: 2019-20.
# Relationships created for Player: Jeremy Lamb for season: 2019-20.
# Relationships created for Player: Jerian Grant for season: 2019-20.
# Relationships created for Player: Jerome Robinson for season: 2019-20.
# Relationships created for Player: Jevon Carter for season: 2019-20.
# Relationships created for Player: Jimmy Butler for season: 2019-20.
# Relationships created for Player: Joe Harris for season: 2019-20.
# Relationships created for Player: Joe Ingles for season: 2019-20.
# Relationships created for Player: Joel Embiid for season: 2019-20.
# Relationships created for Player: John Collins for season: 2019-20.
# Relationships created for Player: John Henson for season: 2019-20.
# Relationships created for Player: John Konchar for season: 2019-20.
# Relationships created for Player: Johnathan Motley for season: 2019-20.
# Relationships created for Player: Johnathan Williams for season: 2019-20.
# Relationships created for Player: Jonas Valanciunas for season: 2019-20.
# Relationships created for Player: Jonathan Isaac for season: 2019-20.
# Relationships created for Player: Jordan Bell for season: 2019-20.
# Relationships created for Player: Jordan Clarkson for season: 2019-20.
# Relationships created for Player: Jordan McLaughlin for season: 2019-20.
# Relationships created for Player: Jordan McRae for season: 2019-20.
# Relationships created for Player: Jordan Poole for season: 2019-20.
# Relationships created for Player: Josh Hart for season: 2019-20.
# Relationships created for Player: Josh Jackson for season: 2019-20.
# Relationships created for Player: Josh Okogie for season: 2019-20.
# Relationships created for Player: Josh Reaves for season: 2019-20.
# Relationships created for Player: Josh Richardson for season: 2019-20.
# Relationships created for Player: Jrue Holiday for season: 2019-20.
# Relationships created for Player: Juan Toscano-Anderson for season: 2019-20.
# Relationships created for Player: Julius Randle for season: 2019-20.
# Relationships created for Player: Justin Holiday for season: 2019-20.
# Relationships created for Player: Justin Jackson for season: 2019-20.
# Relationships created for Player: Justin James for season: 2019-20.
# Relationships created for Player: Justin Wright-Foreman for season: 2019-20.
# Relationships created for Player: Justise Winslow for season: 2019-20.
# Relationships created for Player: Jusuf Nurkic for season: 2019-20.
# Relationships created for Player: Juwan Morgan for season: 2019-20.
# Relationships created for Player: KZ Okpala for season: 2019-20.
# Relationships created for Player: Karl-Anthony Towns for season: 2019-20.
# Relationships created for Player: Kawhi Leonard for season: 2019-20.
# Relationships created for Player: Keita Bates-Diop for season: 2019-20.
# Relationships created for Player: Kelan Martin for season: 2019-20.
# Relationships created for Player: Keldon Johnson for season: 2019-20.
# Relationships created for Player: Kelly Olynyk for season: 2019-20.
# Relationships created for Player: Kemba Walker for season: 2019-20.
# Relationships created for Player: Kendrick Nunn for season: 2019-20.
# Relationships created for Player: Kenrich Williams for season: 2019-20.
# Relationships created for Player: Kent Bazemore for season: 2019-20.
# Relationships created for Player: Kentavious Caldwell-Pope for season: 2019-20.
# Relationships created for Player: Kevin Huerter for season: 2019-20.
# Relationships created for Player: Kevin Love for season: 2019-20.
# Relationships created for Player: Kevon Looney for season: 2019-20.
# Relationships created for Player: Khem Birch for season: 2019-20.
# Relationships created for Player: Khris Middleton for season: 2019-20.
# Relationships created for Player: Khyri Thomas for season: 2019-20.
# Relationships created for Player: Kris Dunn for season: 2019-20.
# Relationships created for Player: Kristaps Porzingis for season: 2019-20.
# Relationships created for Player: Ky Bowman for season: 2019-20.
# Relationships created for Player: Kyle Anderson for season: 2019-20.
# Relationships created for Player: Kyle Korver for season: 2019-20.
# Relationships created for Player: Kyle Kuzma for season: 2019-20.
# Relationships created for Player: Kyle Lowry for season: 2019-20.
# Relationships created for Player: Kyle O'Quinn for season: 2019-20.
# Relationships created for Player: Kyrie Irving for season: 2019-20.
# Relationships created for Player: LaMarcus Aldridge for season: 2019-20.
# Relationships created for Player: Landry Shamet for season: 2019-20.
# Relationships created for Player: Langston Galloway for season: 2019-20.
# Relationships created for Player: Lauri Markkanen for season: 2019-20.
# Relationships created for Player: LeBron James for season: 2019-20.
# Relationships created for Player: Lonzo Ball for season: 2019-20.
# Relationships created for Player: Louis King for season: 2019-20.
# Relationships created for Player: Luguentz Dort for season: 2019-20.
# Relationships created for Player: Luka Doncic for season: 2019-20.
# Relationships created for Player: Luka Samanic for season: 2019-20.
# Relationships created for Player: Luke Kennard for season: 2019-20.
# Relationships created for Player: Luke Kornet for season: 2019-20.
# Relationships created for Player: Malcolm Brogdon for season: 2019-20.
# Relationships created for Player: Malcolm Miller for season: 2019-20.
# Relationships created for Player: Malik Beasley for season: 2019-20.
# Relationships created for Player: Malik Monk for season: 2019-20.
# Relationships created for Player: Marc Gasol for season: 2019-20.
# Relationships created for Player: Marco Belinelli for season: 2019-20.
# Relationships created for Player: Marcus Smart for season: 2019-20.
# Relationships created for Player: Marial Shayok for season: 2019-20.
# Relationships created for Player: Mario Hezonja for season: 2019-20.
# Relationships created for Player: Markelle Fultz for season: 2019-20.
# Relationships created for Player: Markieff Morris for season: 2019-20.
# Relationships created for Player: Marko Guduric for season: 2019-20.
# Relationships created for Player: Marvin Williams for season: 2019-20.
# Relationships created for Player: Mason Plumlee for season: 2019-20.
# Relationships created for Player: Matisse Thybulle for season: 2019-20.
# Relationships created for Player: Matt Thomas for season: 2019-20.
# Relationships created for Player: Matthew Dellavedova for season: 2019-20.
# Relationships created for Player: Maxi Kleber for season: 2019-20.
# Relationships created for Player: Meyers Leonard for season: 2019-20.
# Relationships created for Player: Mfiondu Kabengele for season: 2019-20.
# Relationships created for Player: Michael Carter-Williams for season: 2019-20.
# Relationships created for Player: Michael Kidd-Gilchrist for season: 2019-20.
# Relationships created for Player: Mikal Bridges for season: 2019-20.
# ...
# Relationships created for Player: Jared Butler for season: 2023-24.
# Relationships created for Player: Jared Rhoden for season: 2023-24.
# Relationships created for Player: Jarred Vanderbilt for season: 2023-24.
# Relationships created for Player: Jarrett Allen for season: 2023-24.
# Relationships created for Player: Javon Freeman-Liberty for season: 2023-24.
# Relationships created for Player: Javonte Green for season: 2023-24.
# Relationships created for Player: Jaxson Hayes for season: 2023-24.
# Relationships created for Player: Jay Huff for season: 2023-24.
# Relationships created for Player: Jaylen Brown for season: 2023-24.
# Relationships created for Player: Jayson Tatum for season: 2023-24.
# Relationships created for Player: Jeff Green for season: 2023-24.
# Relationships created for Player: Jerami Grant for season: 2023-24.
# Relationships created for Player: Jeremiah Robinson-Earl for season: 2023-24.
# Relationships created for Player: Jeremy Sochan for season: 2023-24.
# Relationships created for Player: Jerome Robinson for season: 2023-24.
# Relationships created for Player: Jett Howard for season: 2023-24.
# Relationships created for Player: Jevon Carter for season: 2023-24.
# Relationships created for Player: Jimmy Butler for season: 2023-24.
# Relationships created for Player: Jock Landale for season: 2023-24.
# Relationships created for Player: Joe Ingles for season: 2023-24.
# Relationships created for Player: Joel Embiid for season: 2023-24.
# Relationships created for Player: John Collins for season: 2023-24.
# Relationships created for Player: John Konchar for season: 2023-24.
# Relationships created for Player: Johnny Juzang for season: 2023-24.
# Relationships created for Player: Jonas Valanciunas for season: 2023-24.
# Relationships created for Player: Jonathan Isaac for season: 2023-24.
# Relationships created for Player: Jonathan Kuminga for season: 2023-24.
# Relationships created for Player: Jordan Clarkson for season: 2023-24.
# Relationships created for Player: Jordan Ford for season: 2023-24.
# Relationships created for Player: Jordan Goodwin for season: 2023-24.
# Relationships created for Player: Jordan Hawkins for season: 2023-24.
# Relationships created for Player: Jordan McLaughlin for season: 2023-24.
# Relationships created for Player: Jordan Miller for season: 2023-24.
# Relationships created for Player: Jordan Nwora for season: 2023-24.
# Relationships created for Player: Jordan Poole for season: 2023-24.
# Relationships created for Player: Jordan Walsh for season: 2023-24.
# Relationships created for Player: Jose Alvarado for season: 2023-24.
# Relationships created for Player: Josh Giddey for season: 2023-24.
# Relationships created for Player: Josh Green for season: 2023-24.
# Relationships created for Player: Josh Hart for season: 2023-24.
# Relationships created for Player: Josh Minott for season: 2023-24.
# Relationships created for Player: Josh Okogie for season: 2023-24.
# Relationships created for Player: Josh Richardson for season: 2023-24.
# Relationships created for Player: Jrue Holiday for season: 2023-24.
# Relationships created for Player: Jules Bernard for season: 2023-24.
# Relationships created for Player: Julian Champagnie for season: 2023-24.
# Relationships created for Player: Julian Phillips for season: 2023-24.
# Relationships created for Player: Julian Strawther for season: 2023-24.
# Relationships created for Player: Julius Randle for season: 2023-24.
# Relationships created for Player: Justin Champagnie for season: 2023-24.
# Relationships created for Player: Justin Holiday for season: 2023-24.
# Relationships created for Player: Justin Minaya for season: 2023-24.
# Relationships created for Player: Jusuf Nurkic for season: 2023-24.
# Relationships created for Player: KJ Martin for season: 2023-24.
# Relationships created for Player: Karl-Anthony Towns for season: 2023-24.
# Relationships created for Player: Kawhi Leonard for season: 2023-24.
# Relationships created for Player: Keegan Murray for season: 2023-24.
# Relationships created for Player: Keita Bates-Diop for season: 2023-24.
# Relationships created for Player: Keldon Johnson for season: 2023-24.
# Relationships created for Player: Kelly Olynyk for season: 2023-24.
# Relationships created for Player: Kendall Brown for season: 2023-24.
# Relationships created for Player: Kenrich Williams for season: 2023-24.
# Relationships created for Player: Kentavious Caldwell-Pope for season: 2023-24.
# Relationships created for Player: Keon Ellis for season: 2023-24.
# Relationships created for Player: Keon Johnson for season: 2023-24.
# Relationships created for Player: Kessler Edwards for season: 2023-24.
# Relationships created for Player: Kevin Durant for season: 2023-24.
# Relationships created for Player: Kevin Huerter for season: 2023-24.
# Relationships created for Player: Kevin Love for season: 2023-24.
# Relationships created for Player: Kevon Looney for season: 2023-24.
# Relationships created for Player: Keyonte George for season: 2023-24.
# Relationships created for Player: Khris Middleton for season: 2023-24.
# Relationships created for Player: Klay Thompson for season: 2023-24.
# Relationships created for Player: Kobe Brown for season: 2023-24.
# Relationships created for Player: Kobe Bufkin for season: 2023-24.
# Relationships created for Player: Kris Dunn for season: 2023-24.
# Relationships created for Player: Kris Murray for season: 2023-24.
# Relationships created for Player: Kristaps Porzingis for season: 2023-24.
# Relationships created for Player: Kyle Anderson for season: 2023-24.
# Relationships created for Player: Kyle Kuzma for season: 2023-24.
# Relationships created for Player: Kyle Lowry for season: 2023-24.
# Relationships created for Player: Kyrie Irving for season: 2023-24.
# Relationships created for Player: LaMelo Ball for season: 2023-24.
# Relationships created for Player: Lamar Stevens for season: 2023-24.
# Relationships created for Player: Landry Shamet for season: 2023-24.
# Relationships created for Player: Lauri Markkanen for season: 2023-24.
# Relationships created for Player: LeBron James for season: 2023-24.
# Relationships created for Player: Leaky Black for season: 2023-24.
# Relationships created for Player: Leonard Miller for season: 2023-24.
# Relationships created for Player: Lester Quinones for season: 2023-24.
# Relationships created for Player: Lindy Waters III for season: 2023-24.
# Relationships created for Player: Luguentz Dort for season: 2023-24.
# Relationships created for Player: Luka Doncic for season: 2023-24.
# Relationships created for Player: Luka Garza for season: 2023-24.
# Relationships created for Player: Luka Samanic for season: 2023-24.
# Relationships created for Player: Luke Kennard for season: 2023-24.
# Relationships created for Player: Luke Kornet for season: 2023-24.
# Relationships created for Player: Malachi Flynn for season: 2023-24.
# Relationships created for Player: Malaki Branham for season: 2023-24.
# Relationships created for Player: Malcolm Brogdon for season: 2023-24.
# Relationships created for Player: Malik Beasley for season: 2023-24.
# Relationships created for Player: Malik Monk for season: 2023-24.
# Relationships created for Player: Malik Williams for season: 2023-24.
# Relationships created for Player: MarJon Beauchamp for season: 2023-24.
# Relationships created for Player: Marcus Sasser for season: 2023-24.
# Relationships created for Player: Marcus Smart for season: 2023-24.
# Relationships created for Player: Markelle Fultz for season: 2023-24.
# Relationships created for Player: Markieff Morris for season: 2023-24.
# Relationships created for Player: Mason Jones for season: 2023-24.
# Relationships created for Player: Mason Plumlee for season: 2023-24.
# Relationships created for Player: Matisse Thybulle for season: 2023-24.
# Relationships created for Player: Max Christie for season: 2023-24.
# Relationships created for Player: Max Strus for season: 2023-24.
# Relationships created for Player: Maxi Kleber for season: 2023-24.
# Relationships created for Player: Maxwell Lewis for season: 2023-24.
# Relationships created for Player: Micah Potter for season: 2023-24.
# Relationships created for Player: Mikal Bridges for season: 2023-24.
# Relationships created for Player: Mike Conley for season: 2023-24.
# Relationships created for Player: Mike Muscala for season: 2023-24.
# Relationships created for Player: Miles Bridges for season: 2023-24.
# Relationships created for Player: Miles McBride for season: 2023-24.
# Relationships created for Player: Mo Bamba for season: 2023-24.
# Relationships created for Player: Monte Morris for season: 2023-24.
# Relationships created for Player: Moritz Wagner for season: 2023-24.
# Relationships created for Player: Moses Moody for season: 2023-24.
# Relationships created for Player: Mouhamadou Gueye for season: 2023-24.
# Relationships created for Player: Mouhamed Gueye for season: 2023-24.
# Relationships created for Player: Myles Turner for season: 2023-24.
# Relationships created for Player: Naji Marshall for season: 2023-24.
# Relationships created for Player: Nassir Little for season: 2023-24.
# Relationships created for Player: Nate Hinton for season: 2023-24.
# Relationships created for Player: Naz Reid for season: 2023-24.
# Relationships created for Player: Nickeil Alexander-Walker for season: 2023-24.
# Relationships created for Player: Nikola Jokic for season: 2023-24.
# Relationships created for Player: Nikola Jovic for season: 2023-24.
# Relationships created for Player: Nikola Vucevic for season: 2023-24.
# Relationships created for Player: Noah Clowney for season: 2023-24.
# Relationships created for Player: Norman Powell for season: 2023-24.
# Relationships created for Player: OG Anunoby for season: 2023-24.
# Relationships created for Player: Obi Toppin for season: 2023-24.
# Relationships created for Player: Ochai Agbaji for season: 2023-24.
# Relationships created for Player: Olivier Sarr for season: 2023-24.
# Relationships created for Player: Olivier-Maxence Prosper for season: 2023-24.
# Relationships created for Player: Omer Yurtseven for season: 2023-24.
# Relationships created for Player: Onuralp Bitim for season: 2023-24.
# Relationships created for Player: Onyeka Okongwu for season: 2023-24.
# Relationships created for Player: Orlando Robinson for season: 2023-24.
# Relationships created for Player: Oshae Brissett for season: 2023-24.
# Relationships created for Player: Ousmane Dieng for season: 2023-24.
# Relationships created for Player: Paolo Banchero for season: 2023-24.
# Relationships created for Player: Pascal Siakam for season: 2023-24.
# Relationships created for Player: Pat Connaughton for season: 2023-24.
# Relationships created for Player: Patrick Beverley for season: 2023-24.
# Relationships created for Player: Patrick Williams for season: 2023-24.
# Relationships created for Player: Paul George for season: 2023-24.
# Relationships created for Player: Paul Reed for season: 2023-24.
# Relationships created for Player: Payton Pritchard for season: 2023-24.
# Relationships created for Player: Pete Nance for season: 2023-24.
# Relationships created for Player: Peyton Watson for season: 2023-24.
# Relationships created for Player: Precious Achiuwa for season: 2023-24.
# Relationships created for Player: Quentin Grimes for season: 2023-24.
# Relationships created for Player: RJ Barrett for season: 2023-24.
# Relationships created for Player: Rayan Rupert for season: 2023-24.
# Relationships created for Player: Reggie Jackson for season: 2023-24.
# Relationships created for Player: Robert Covington for season: 2023-24.
# Relationships created for Player: Royce O'Neale for season: 2023-24.
# Relationships created for Player: Rudy Gobert for season: 2023-24.
# Relationships created for Player: Rui Hachimura for season: 2023-24.
# Relationships created for Player: Russell Westbrook for season: 2023-24.
# Relationships created for Player: Ryan Rollins for season: 2023-24.
# Relationships created for Player: Saben Lee for season: 2023-24.
# Relationships created for Player: Saddiq Bey for season: 2023-24.
# Relationships created for Player: Sam Hauser for season: 2023-24.
# Relationships created for Player: Sam Merrill for season: 2023-24.
# Relationships created for Player: Sandro Mamukelashvili for season: 2023-24.
# Relationships created for Player: Sasha Vezenkov for season: 2023-24.
# Relationships created for Player: Scoot Henderson for season: 2023-24.
# Relationships created for Player: Scottie Barnes for season: 2023-24.
# Relationships created for Player: Seth Curry for season: 2023-24.
# Relationships created for Player: Seth Lundy for season: 2023-24.
# Relationships created for Player: Shaedon Sharpe for season: 2023-24.
# Relationships created for Player: Shai Gilgeous-Alexander for season: 2023-24.
# Relationships created for Player: Shake Milton for season: 2023-24.
# Relationships created for Player: Sidy Cissoko for season: 2023-24.
# Relationships created for Player: Simone Fontecchio for season: 2023-24.
# Relationships created for Player: Skylar Mays for season: 2023-24.
# Relationships created for Player: Spencer Dinwiddie for season: 2023-24.
# Relationships created for Player: Stanley Umude for season: 2023-24.
# Relationships created for Player: Stephen Curry for season: 2023-24.
# Relationships created for Player: Taj Gibson for season: 2023-24.
# Relationships created for Player: Talen Horton-Tucker for season: 2023-24.
# Relationships created for Player: Tari Eason for season: 2023-24.
# Relationships created for Player: Taurean Prince for season: 2023-24.
# Relationships created for Player: Taylor Hendricks for season: 2023-24.
# Relationships created for Player: Terance Mann for season: 2023-24.
# Relationships created for Player: Terquavion Smith for season: 2023-24.
# Relationships created for Player: Terry Rozier for season: 2023-24.
# Relationships created for Player: Thaddeus Young for season: 2023-24.
# Relationships created for Player: Thanasis Antetokounmpo for season: 2023-24.
# Relationships created for Player: Thomas Bryant for season: 2023-24.
# Relationships created for Player: Tobias Harris for season: 2023-24.
# Relationships created for Player: Torrey Craig for season: 2023-24.
# Relationships created for Player: Toumani Camara for season: 2023-24.
# Relationships created for Player: Trae Young for season: 2023-24.
# Relationships created for Player: Trayce Jackson-Davis for season: 2023-24.
# Relationships created for Player: Tre Jones for season: 2023-24.
# Relationships created for Player: Tre Mann for season: 2023-24.
# Relationships created for Player: Trendon Watford for season: 2023-24.
# Relationships created for Player: Trent Forrest for season: 2023-24.
# Relationships created for Player: Trevelin Queen for season: 2023-24.
# Relationships created for Player: Trey Lyles for season: 2023-24.
# Relationships created for Player: Tristan Thompson for season: 2023-24.
# Relationships created for Player: Tristan Vukcevic for season: 2023-24.
# Relationships created for Player: Tyler Herro for season: 2023-24.
# Relationships created for Player: Tyrese Haliburton for season: 2023-24.
# Relationships created for Player: Tyrese Maxey for season: 2023-24.
# Relationships created for Player: Tyus Jones for season: 2023-24.
# Relationships created for Player: Usman Garuba for season: 2023-24.
# Relationships created for Player: Vasilije Micic for season: 2023-24.
# Relationships created for Player: Vit Krejci for season: 2023-24.
# Relationships created for Player: Walker Kessler for season: 2023-24.
# Relationships created for Player: Wesley Matthews for season: 2023-24.
# Relationships created for Player: Xavier Moon for season: 2023-24.
# Relationships created for Player: Xavier Tillman for season: 2023-24.
# Relationships created for Player: Yuta Watanabe for season: 2023-24.
# Relationships created for Player: Zach Collins for season: 2023-24.
# Relationships created for Player: Zach LaVine for season: 2023-24.
# Relationships created for Player: Zeke Nnaji for season: 2023-24.
# Relationships created for Player: Ziaire Williams for season: 2023-24.
# Relationships created for Player: Zion Williamson for season: 2023-24.
# Data reinserted into a clean Neo4j database with renamed total columns.

# %% [markdown]
# Neo4j example pull:

# %%
from neo4j import GraphDatabase
import os
from dotenv import load_dotenv


# Print the current working directory (optional for debugging)
print(os.getcwd())

# Set the path to your .env file relative to the current working directory
dotenv_path = os.path.join(os.getcwd(), '../../.env')
load_dotenv(dotenv_path)

# Neo4j connection parameters from .env
uri = os.getenv("NEO4J_URI")
username = os.getenv("NEO4J_USERNAME")
password = os.getenv("NEO4J_PASSWORD")

# Create a Neo4j driver using the Aura connection details
driver = GraphDatabase.driver(uri, auth=(username, password))
# Out:
# /workspaces/custom_ollama_docker/notebooks/neo4j_data_setup

# %%
from neo4j import GraphDatabase
import pandas as pd

nba_player_inflated_data = pd.read_csv('../../data/neo4j/raw/nba_player_data_final_inflated.csv')

print(nba_player_inflated_data)

# Function to run a Cypher query and return a Pandas DataFrame
def query_to_dataframe(driver, query, parameters=None):
    """
    Executes a Cypher query and returns the results as a Pandas DataFrame.

    :param driver: Neo4j database driver instance.
    :param query: Cypher query string to execute.
    :param parameters: Optional dictionary of query parameters.
    :return: Pandas DataFrame with query results.
    """
    with driver.session() as session:
        result = session.run(query, parameters)
        # Extract column names and data from the result
        columns = result.keys()
        data = [record.values() for record in result]
        # Create a DataFrame from the extracted data
        return pd.DataFrame(data, columns=columns)


query = """
MATCH (p:Player)-[:PARTICIPATED_IN]->(s:Season {name: "2023-24"})
RETURN p.name AS player_name, stat.assists_total, stat.games_played

"""

# Execute the query and return the result as a DataFrame
extra_columns_df = query_to_dataframe(driver, query)

# Display the first few rows of the DataFrame
print(extra_columns_df.head())
# Out:
#        Season           Player        Position   Age Team        TeamID  \
# 0     2018-19     Aaron Gordon         Forward  23.0  ORL  1.610613e+09
# 1     2018-19    Aaron Holiday           Guard  22.0  IND  1.610613e+09
# 2     2018-19      Abdel Nader         Forward  25.0  OKC  1.610613e+09
# 3     2018-19       Al Horford  Center-Forward  33.0  BOS  1.610613e+09
# 4     2018-19  Al-Farouq Aminu         Forward  28.0  POR  1.610613e+09
# ...       ...              ...             ...   ...  ...           ...
# 2780  2023-24      Zach LaVine           Guard  29.0  CHI  1.610613e+09
# 2781  2023-24   Zavier Simpson           Guard  27.0  MEM  0.000000e+00
# 2782  2023-24       Zeke Nnaji  Forward-Center  23.0  DEN  1.610613e+09
# 2783  2023-24  Ziaire Williams         Forward  22.0  MEM  1.610613e+09
# 2784  2023-24  Zion Williamson         Forward  23.0  NOP  1.610613e+09
#
#       Years of Service    GP    GS      MP  ...  Injury_Risk   Salary Cap  \
# 0                  4.0  78.0  78.0  2633.0  ...     Low Risk  101869000.0
# 1                  0.0  50.0   0.0   646.0  ...     Low Risk  101869000.0
# 2                  2.0  61.0   1.0   694.0  ...     Low Risk  101869000.0
# 3                 11.0  68.0  68.0  1973.0  ...    High Risk  101869000.0
# 4                  8.0  81.0  81.0  2292.0  ...     Low Risk  101869000.0
# ...                ...   ...   ...     ...  ...          ...          ...
# 2780               9.0  25.0  23.0   872.0  ...     Low Risk  136021000.0
# 2781               2.0   7.0   0.0   161.0  ...     Low Risk  136021000.0
# 2782               3.0  58.0   0.0   576.0  ...     Low Risk  136021000.0
# 2783               2.0  51.0  15.0  1038.0  ...     Low Risk  136021000.0
# 2784               4.0  70.0  70.0  2207.0  ...     Low Risk  136021000.0
#
#        Luxury Tax    1st Apron        BAE  Standard /Non-Taxpayer   Taxpayer  \
# 0     123733000.0  129817000.0  3382000.0               8641000.0  5337000.0
# 1     123733000.0  129817000.0  3382000.0               8641000.0  5337000.0
# 2     123733000.0  129817000.0  3382000.0               8641000.0  5337000.0
# 3     123733000.0  129817000.0  3382000.0               8641000.0  5337000.0
# 4     123733000.0  129817000.0  3382000.0               8641000.0  5337000.0
# ...           ...          ...        ...                     ...        ...
# 2780  165294000.0  172346000.0  4516000.0              12405000.0  5000000.0
# 2781  165294000.0  172346000.0  4516000.0              12405000.0  5000000.0
# 2782  165294000.0  172346000.0  4516000.0              12405000.0  5000000.0
# 2783  165294000.0  172346000.0  4516000.0              12405000.0  5000000.0
# 2784  165294000.0  172346000.0  4516000.0              12405000.0  5000000.0
#
#       Team Room /Under Cap  Salary_Cap_Inflated    2nd Apron
# 0                4449000.0         1.187242e+08          NaN
# 1                4449000.0         1.187242e+08          NaN
# 2                4449000.0         1.187242e+08          NaN
# 3                4449000.0         1.187242e+08          NaN
# 4                4449000.0         1.187242e+08          NaN
# ...                    ...                  ...          ...
# 2780             7723000.0         1.306431e+08  182794000.0
# 2781             7723000.0         1.306431e+08  182794000.0
# 2782             7723000.0         1.306431e+08  182794000.0
# 2783             7723000.0         1.306431e+08  182794000.0
# 2784             7723000.0         1.306431e+08  182794000.0
#
# [2785 rows x 66 columns]
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# Cell In[2], line 34
#      27 query = """
#      28 MATCH (p:Player)-[:PARTICIPATED_IN]->(s:Season {name: "2023-24"})
#      29 RETURN p.name AS player_name, stat.assists_total, stat.games_played
#      30
#      31 """
#      33 # Execute the query and return the result as a DataFrame
# ---> 34 extra_columns_df = query_to_dataframe(driver, query)
#      36 # Display the first few rows of the DataFrame
#      37 print(extra_columns_df.head())
#
# Cell In[2], line 19, in query_to_dataframe(driver, query, parameters)
#      10 """
#      11 Executes a Cypher query and returns the results as a Pandas DataFrame.
#      12
#    (...)
#      16 :return: Pandas DataFrame with query results.
#      17 """
#      18 with driver.session() as session:
# ---> 19     result = session.run(query, parameters)
#      20     # Extract column names and data from the result
#      21     columns = result.keys()
#
# File /opt/conda/envs/data_science_ollama/lib/python3.10/site-packages/neo4j/_sync/work/session.py:320, in Session.run(self, query, parameters, **kwargs)
#     318 bookmarks = self._get_bookmarks()
#     319 parameters = dict(parameters or {}, **kwargs)
# --> 320 self._auto_result._run(
#     321     query,
#     322     parameters,
#     323     self._config.database,
#     324     self._config.impersonated_user,
#     325     self._config.default_access_mode,
#     326     bookmarks,
#     327     self._config.notifications_min_severity,
#     328     self._config.notifications_disabled_classifications,
#     329 )
#     331 return self._auto_result
#
# File /opt/conda/envs/data_science_ollama/lib/python3.10/site-packages/neo4j/_sync/work/result.py:231, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     229 self._pull()
#     230 self._connection.send_all()
# --> 231 self._attach()
#
# File /opt/conda/envs/data_science_ollama/lib/python3.10/site-packages/neo4j/_sync/work/result.py:425, in Result._attach(self)
#     423 if self._exhausted is False:
#     424     while self._attached is False:
# --> 425         self._connection.fetch_message()
#
# File /opt/conda/envs/data_science_ollama/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:181, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     179 def inner(*args, **kwargs):
#     180     try:
# --> 181         func(*args, **kwargs)
#     182     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     183         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File /opt/conda/envs/data_science_ollama/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:977, in Bolt.fetch_message(self)
#     973 # Receive exactly one message
#     974 tag, fields = self.inbox.pop(
#     975     hydration_hooks=self.responses[0].hydration_hooks
#     976 )
# --> 977 res = self._process_message(tag, fields)
#     978 self.idle_since = monotonic()
#     979 return res
#
# File /opt/conda/envs/data_science_ollama/lib/python3.10/site-packages/neo4j/_sync/io/_bolt5.py:466, in Bolt5x0._process_message(self, tag, fields)
#     464 self._server_state_manager.state = self.bolt_states.FAILED
#     465 try:
# --> 466     response.on_failure(summary_metadata or {})
#     467 except (ServiceUnavailable, DatabaseUnavailable):
#     468     if self.pool:
#
# File /opt/conda/envs/data_science_ollama/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:251, in Response.on_failure(self, metadata)
#     249 handler = self.handlers.get("on_summary")
#     250 Util.callback(handler)
# --> 251 raise Neo4jError.hydrate(**metadata)
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Variable `stat` not defined (line 3, column 31 (offset: 97))
# "RETURN p.name AS player_name, stat.assists_total, stat.games_played"
#                                ^}

# %%
query = """
MATCH (stat:Statistics)
RETURN stat.player AS player, stat.games_played AS games_played
LIMIT 10

"""

# Execute the query and return the result as a DataFrame
extra_columns_df = query_to_dataframe(driver, query)

# Display the first few rows of the DataFrame
print(extra_columns_df.head())
# Out:
#             player  games_played
# 0     Aaron Gordon          78.0
# 1    Aaron Holiday          50.0
# 2      Abdel Nader          61.0
# 3       Al Horford          68.0
# 4  Al-Farouq Aminu          81.0

# %%
# Define a Cypher query to pull player contracts for a specific season
query = """
MATCH (p:Player)-[:HAS_CONTRACT]->(c:Contract {season: $season})
RETURN p.name AS player, c.salary AS salary, c.season AS season, c.team_option AS team_option,
       c.player_option AS player_option, c.no_trade_clause AS no_trade_clause
"""
parameters = {"season": "2023-24"}  # Replace with your target season

# Execute the query and return the result as a DataFrame
player_contracts_df = query_to_dataframe(driver, query, parameters)

# Display the first few rows of the DataFrame
print(player_contracts_df.head())
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: team_option)} {position: line: 3, column: 68, offset: 133} for query: '\nMATCH (p:Player)-[:HAS_CONTRACT]->(c:Contract {season: $season})\nRETURN p.name AS player, c.salary AS salary, c.season AS season, c.team_option AS team_option,\n       c.player_option AS player_option, c.no_trade_clause AS no_trade_clause\n'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: player_option)} {position: line: 4, column: 10, offset: 170} for query: '\nMATCH (p:Player)-[:HAS_CONTRACT]->(c:Contract {season: $season})\nRETURN p.name AS player, c.salary AS salary, c.season AS season, c.team_option AS team_option,\n       c.player_option AS player_option, c.no_trade_clause AS no_trade_clause\n'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: no_trade_clause)} {position: line: 4, column: 44, offset: 204} for query: '\nMATCH (p:Player)-[:HAS_CONTRACT]->(c:Contract {season: $season})\nRETURN p.name AS player, c.salary AS salary, c.season AS season, c.team_option AS team_option,\n       c.player_option AS player_option, c.no_trade_clause AS no_trade_clause\n'
#           player      salary   season team_option player_option  \
# 0       AJ Green   1901769.0  2023-24        None          None
# 1     AJ Griffin   3712920.0  2023-24        None          None
# 2      AJ Lawson   1000000.0  2023-24        None          None
# 3   Aaron Gordon  21266182.0  2023-24        None          None
# 4  Aaron Holiday   2346614.0  2023-24        None          None
#
#   no_trade_clause
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
# Define a Cypher query to pull player statistics for a specific season
query = """
MATCH (p:Player)-[:POSSESSES]->(stat:Statistics {season: $season})
RETURN p.name AS player, stat.ppg AS points_per_game, stat.assists AS assists, stat.rebounds AS rebounds,
       stat.per AS player_efficiency_rating, stat.vorp AS value_over_replacement
"""
parameters = {"season": "2023-24"}  # Replace with your target season

# Execute the query and return the result as a DataFrame
player_stats_df = query_to_dataframe(driver, query, parameters)

# Display the first few rows of the DataFrame
print(player_stats_df.head())
# Out:
#           player  points_per_game assists rebounds player_efficiency_rating  \
# 0   Aaron Gordon           1013.0    None     None                     None
# 1  Aaron Holiday            514.0    None     None                     None
# 2     Al Horford            562.0    None     None                     None
# 3     Alec Burks            540.0    None     None                     None
# 4    Alex Caruso            715.0    None     None                     None
#
#   value_over_replacement
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None

# %%
query_templates = {
    "player_contracts": """
        MATCH (p:Player)-[:HAS_CONTRACT]->(c:Contract {season: $season})
        RETURN p.name AS player, c.salary AS salary
    """,
    "player_stats": """
        MATCH (p:Player)-[:POSSESSES]->(stat:Statistics {season: $season})
        RETURN p.name AS player, stat.ppg AS points_per_game, stat.assists AS assists
    """
}

# Example function to use query templates
def get_player_data_from_neo4j(driver, query_name, season):
    query = query_templates.get(query_name)
    if query:
        parameters = {"season": season}
        return query_to_dataframe(driver, query, parameters)
    else:
        print(f"Query '{query_name}' not found.")
        return None

# Retrieve data using a specific query template
player_stats = get_player_data_from_neo4j(driver, "player_stats", "2023-24")
print(player_stats.head())
# Out:
#           player  points_per_game assists
# 0   Aaron Gordon           1013.0    None
# 1  Aaron Holiday            514.0    None
# 2     Al Horford            562.0    None
# 3     Alec Burks            540.0    None
# 4    Alex Caruso            715.0    None

# %%
from neo4j import GraphDatabase
import pandas as pd

# Function to run a Cypher query and return a Pandas DataFrame
def query_to_dataframe(driver, query, parameters=None):
    """
    Executes a Cypher query and returns the results as a Pandas DataFrame.

    :param driver: Neo4j database driver instance.
    :param query: Cypher query string to execute.
    :param parameters: Optional dictionary of query parameters.
    :return: Pandas DataFrame with query results.
    """
    with driver.session() as session:
        result = session.run(query, parameters)
        # Extract column names and data from the result
        columns = result.keys()
        data = [record.values() for record in result]
        # Create a DataFrame from the extracted data
        return pd.DataFrame(data, columns=columns)

# Sample queries to retrieve data from Neo4j
def get_player_statistics(driver, season):
    query = """
    MATCH (p:Player)-[:POSSESSES]->(stat:Statistics {season: $season})
    RETURN p.name AS player, stat.ppg AS points_per_game, stat.assists AS assists, stat.rebounds AS rebounds,
           stat.per AS player_efficiency_rating, stat.vorp AS value_over_replacement
    """
    parameters = {"season": season}
    return query_to_dataframe(driver, query, parameters)

def get_player_contracts(driver, season):
    query = """
    MATCH (p:Player)-[:HAS_CONTRACT]->(c:Contract {season: $season})
    RETURN p.name AS player, c.salary AS salary, c.team_option AS team_option, c.player_option AS player_option,
           c.no_trade_clause AS no_trade_clause
    """
    parameters = {"season": season}
    return query_to_dataframe(driver, query, parameters)

# Connect to Neo4j
driver = GraphDatabase.driver(uri, auth=(username, password))

# Retrieve player statistics and contracts for the 2023-24 season
player_stats_df = get_player_statistics(driver, "2023-24")
player_contracts_df = get_player_contracts(driver, "2023-24")

# Preview the retrieved data
print(player_stats_df.head())
print(player_contracts_df.head())
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: team_option)} {position: line: 3, column: 52, offset: 121} for query: '\n    MATCH (p:Player)-[:HAS_CONTRACT]->(c:Contract {season: $season})\n    RETURN p.name AS player, c.salary AS salary, c.team_option AS team_option, c.player_option AS player_option,\n           c.no_trade_clause AS no_trade_clause\n    '
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: player_option)} {position: line: 3, column: 82, offset: 151} for query: '\n    MATCH (p:Player)-[:HAS_CONTRACT]->(c:Contract {season: $season})\n    RETURN p.name AS player, c.salary AS salary, c.team_option AS team_option, c.player_option AS player_option,\n           c.no_trade_clause AS no_trade_clause\n    '
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: no_trade_clause)} {position: line: 4, column: 14, offset: 196} for query: '\n    MATCH (p:Player)-[:HAS_CONTRACT]->(c:Contract {season: $season})\n    RETURN p.name AS player, c.salary AS salary, c.team_option AS team_option, c.player_option AS player_option,\n           c.no_trade_clause AS no_trade_clause\n    '
#           player  points_per_game assists rebounds player_efficiency_rating  \
# 0   Aaron Gordon           1013.0    None     None                     None
# 1  Aaron Holiday            514.0    None     None                     None
# 2     Al Horford            562.0    None     None                     None
# 3     Alec Burks            540.0    None     None                     None
# 4    Alex Caruso            715.0    None     None                     None
#
#   value_over_replacement
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
#           player      salary team_option player_option no_trade_clause
# 0       AJ Green   1901769.0        None          None            None
# 1     AJ Griffin   3712920.0        None          None            None
# 2      AJ Lawson   1000000.0        None          None            None
# 3   Aaron Gordon  21266182.0        None          None            None
# 4  Aaron Holiday   2346614.0        None          None            None

# %%
import ollama

# llm = 'llama3.2'
llm = 'tomasonjo/llama3-text2cypher-demo'
response = ollama.chat(model=llm, messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# Out:
# The sky appears blue because of a phenomenon called Rayleigh scattering, named after the British physicist Lord Rayleigh. He first discovered that shorter wavelengths of light (like blue and violet) are scattered more than longer wavelengths (like red and orange) by tiny molecules of gases in the atmosphere, such as nitrogen and oxygen.
#
# Here's how it works:
#
# 1. **Sunlight**: When sunlight enters Earth's atmosphere, it contains all the colors of the visible spectrum.
# 2. **Scattering**: As the light travels through the air, it encounters tiny molecules of gases like N2 (nitrogen) and O2 (oxygen). These molecules scatter the light in all directions, but not evenly.
# 3. **Blue light scattered more**: Shorter wavelengths like blue and violet are scattered by these small molecules more than longer wavelengths like red and orange. This is because they have a higher frequency and interact more strongly with the tiny molecules.
# 4. **Sky appears blue**: As a result of this scattering, our eyes perceive the sky as blue because we see more blue light being scattered in all directions than any other color. The amount of scattering depends on various factors like atmospheric conditions, time of day, and distance from the sun.
#
# Additionally, there are some minor reasons why the sky may appear different shades of blue:
#
# * **Dust and water vapor**: Tiny particles in the air can scatter light and give the sky a more hazy or grayish tint.
# * **Clouds**: Clouds can reflect and scatter sunlight, making the sky appear whiter or grayer.
# * **Atmospheric conditions**: Pollution, smoke, and other atmospheric particles can affect the scattering of light, changing the color of the sky.
#
# So, to summarize: the sky appears blue because of Rayleigh scattering, which favors shorter wavelengths like blue and violet over longer wavelengths.

# %%
from langchain_ollama import ChatOllama
from langchain.schema import HumanMessage
from langchain.chains.graph_qa.cypher import GraphCypherQAChain
from langchain.prompts import PromptTemplate
from langchain_community.graphs import Neo4jGraph
from neo4j import GraphDatabase
from langchain_experimental.utilities import PythonREPL
from langchain_core.tools import Tool
import os
from dotenv import load_dotenv
import re

# Step 1: Load environment variables and establish Neo4j connection
dotenv_path = os.path.join(os.getcwd(), '../../.env')
load_dotenv(dotenv_path)
uri = os.getenv("NEO4J_URI")
username = os.getenv("NEO4J_USERNAME")
password = os.getenv("NEO4J_PASSWORD")

# Create a Neo4j driver using connection details
driver = GraphDatabase.driver(uri, auth=(username, password))

# Create a Neo4jGraph object using the driver
graph = Neo4jGraph(url=uri, username=username, password=password)

# Step 2: Initialize the local LLM model (e.g., Llama 3.2)
cypher_model = 'tomasonjo/llama3-text2cypher-demo'
llm = ChatOllama(model=cypher_model, temperature=0)

# Define the schema for the graph, fixing VORP issue and capitalized properties
schema = """
Nodes:
- Player: Represents an NBA player. Properties: name, age, position, years_of_service, injury_risk, season_salary, season, per, ws, bpm, vorp.
- Team: Represents an NBA team. Properties: name, team_id, needs, strategy, cap_space.
- Season: Represents a specific NBA season. Properties: name.
- Contract: Represents player contracts. Properties: player_name, salary, cap, luxury_tax, duration, player_option, team_option, no_trade_clause.
- Statistics: Represents player statistics. Properties: player, season, ppg, assists_total, rebounds_total, steals_total, blocks_total, turnovers_total, personal_fouls_total, win_shares_total, offensive_win_shares_total, defensive_win_shares_total, vorp_total, games_played.
- Injury: Represents player injury details. Properties: player, total_days, injury_periods, risk, injury_history.

Relationships:
- Player -[:HAS_PLAYED_FOR]-> Team
- Player -[:PARTICIPATED_IN]-> Season
- Player -[:HAS_CONTRACT]-> Contract
- Player -[:POSSESSES]-> Statistics
- Player -[:SUFFERED]-> Injury
- Team -[:HAS_PLAYER]-> Player
- Team -[:CURRENT_TEAM]-> Player
"""

# Step 3: Define the Cypher query prompt with the schema context
cypher_prompt = PromptTemplate(
    template="""
    You are a Cypher query expert for a Neo4j database with the following schema:
    
    Schema:
    {schema}
    
    Use the schema above to generate a Cypher query that answers the given question.
    Make the query flexible by using case-insensitive matching and partial string matching where appropriate.
    Focus on searching player statistics, contracts, and team details.

    Now, generate a Cypher query for the following question:

    Question: {question}
    
    Cypher Query:
    """,
    input_variables=["schema", "question"],
)

# Step 4: Create the GraphCypherQAChain
graph_rag_chain = GraphCypherQAChain.from_llm(
    cypher_llm=llm,
    qa_llm=llm,
    validate_cypher=True,
    graph=graph,
    verbose=True,
    return_intermediate_steps=True,
    return_direct=True,
    cypher_prompt=cypher_prompt,
    allow_dangerous_requests=True,
)

# Step 5: Define a function to check property names against the actual schema
def validate_generated_query(query, driver, schema):
    """Validates the generated Cypher query against the actual schema to identify potential issues."""
    
    # Strip out descriptions from the schema to ensure clean property names
    schema_properties = [
        re.sub(r'\.\n-.*$', '', prop.strip().lower())  # Removes any extra description after the property name
        for prop in schema.split("Properties: ")[1].split(",")
    ]

    # Run a Cypher query to retrieve the property keys from the database for validation
    with driver.session() as session:
        result = session.run("CALL db.schema.nodeTypeProperties()")
        db_properties = {record["propertyName"].lower() for record in result}

    # Identify missing properties
    missing_properties = [prop for prop in schema_properties if prop not in db_properties]
    
    # Debugging logs
    print(f"Schema Properties: {schema_properties}")
    print(f"Database Properties: {db_properties}")
    print(f"Missing Properties: {missing_properties}")
    
    # Return missing properties
    return missing_properties

# Step 6: Define a function to handle missing properties
def handle_missing_properties(missing_properties, query):
    """Removes references to missing properties from the Cypher query."""
    if not missing_properties:
        return query
    
    for prop in missing_properties:
        # Simple removal of the property reference in the query
        query = re.sub(fr"stat\.{prop}\s*", '', query)
    print(f"Adjusted Query After Removing Missing Properties:\n{query}")
    return query

# Step 7: Define a function to handle per-game and average calculations
def add_per_game_calculations(query):
    """
    Adds logic for per-game statistics, such as points per game or assists per game,
    by dividing the cumulative stats by the number of games played.
    """
    print(f"Original Query Before Per-Game Calculations:\n{query}")
    
    # Map cumulative stat fields to their per-game equivalents
    total_stat_mappings = {
        "ppg": "stat.ppg / stat.games_played",
        "assists_total": "stat.assists_total / stat.games_played",
        "rebounds_total": "stat.rebounds_total / stat.games_played",
        "steals_total": "stat.steals_total / stat.games_played",
        "blocks_total": "stat.blocks_total / stat.games_played",
        "turnovers_total": "stat.turnovers_total / stat.games_played",
        "personal_fouls_total": "stat.personal_fouls_total / stat.games_played",
        "win_shares_total": "stat.win_shares_total / stat.games_played",
        "offensive_win_shares_total": "stat.offensive_win_shares_total / stat.games_played",
        "defensive_win_shares_total": "stat.defensive_win_shares_total / stat.games_played",
        "vorp_total": "stat.vorp_total / stat.games_played",
    }
    
    # Apply replacements for per-game calculations in the query
    for total_stat, per_game_stat in total_stat_mappings.items():
        query = re.sub(fr"stat\.{total_stat}", per_game_stat, query, flags=re.IGNORECASE)

    print(f"Adjusted Query After Per-Game Calculations:\n{query}")
    return query

# Step 8: Define a function to execute the Cypher query and get results from Neo4j
def run_cypher_query(query, driver):
    """Executes the given Cypher query on the Neo4j database and returns the results."""
    print(f"Executing Query:\n{query}")
    
    with driver.session() as session:
        result = session.run(query)
        return [record.data() for record in result]

# Step 9: Python REPL tool integration
python_repl = PythonREPL()

# Create a Tool for the agent to interact with the PythonREPL
repl_tool = Tool(
    name="python_repl",
    description="A Python shell. Use this to execute python commands. Input should be a valid python command. If you want to see the output of a value, you should print it out with `print(...)`.",
    func=python_repl.run,
)

# Step 10: Agent automatically using Python REPL to resolve issues in Cypher query generation
def agent_repl_loop(sample_question, schema, driver, llm, repl_tool):
    """
    The agent uses this loop to debug the Cypher query generation and execution process autonomously.
    If an error occurs, the agent uses the Python REPL to reason through and resolve issues.
    """
    while True:
        try:
            # Step 1: Generate the initial Cypher query
            prompt_text = cypher_prompt.format(schema=schema, question=sample_question)
            print(f"Generated Prompt:\n{prompt_text}")
            llm_response = llm([HumanMessage(content=prompt_text)])
            llm_response_content = llm_response.content.strip()
            
            print(f"Extracted Cypher Query:\n{llm_response_content}")
            
            # Step 4: Add per-game calculations if needed
            llm_response_content = add_per_game_calculations(llm_response_content)
            
            # Step 5: Execute the Cypher query in Neo4j and return results
            print(f"Executing adjusted query:\n{llm_response_content}")
            query_result = run_cypher_query(llm_response_content, driver)
            
            # Print the query results
            print("Query Results:")
            for record in query_result:
                print(record)
            
            # Break the loop after successful execution
            break
        
        except Exception as e:
            # Error handling and automatic REPL usage by the agent
            print(f"Error occurred: {e}")
            # Agent uses Python REPL tool to resolve the error
            python_code = f"print('{str(e)}')"
            repl_output = repl_tool.func(python_code)
            print(f"Python REPL Output for Debugging:\n{repl_output}")
            break

# Run a test question
sample_question = "Who are the top 5 players in the 2023-24 season based on assist total?"
agent_repl_loop(sample_question, schema, driver, llm, repl_tool)
# Out:
# Generated Prompt:
#
#     You are a Cypher query expert for a Neo4j database with the following schema:
#
#     Schema:
#
# Nodes:
# - Player: Represents an NBA player. Properties: name, age, position, years_of_service, injury_risk, season_salary, season, per, ws, bpm, vorp.
# - Team: Represents an NBA team. Properties: name, team_id, needs, strategy, cap_space.
# - Season: Represents a specific NBA season. Properties: name.
# - Contract: Represents player contracts. Properties: player_name, salary, cap, luxury_tax, duration, player_option, team_option, no_trade_clause.
# - Statistics: Represents player statistics. Properties: player, season, ppg, assists_total, rebounds_total, steals_total, blocks_total, turnovers_total, personal_fouls_total, win_shares_total, offensive_win_shares_total, defensive_win_shares_total, vorp_total, games_played.
# - Injury: Represents player injury details. Properties: player, total_days, injury_periods, risk, injury_history.
#
# Relationships:
# - Player -[:HAS_PLAYED_FOR]-> Team
# - Player -[:PARTICIPATED_IN]-> Season
# - Player -[:HAS_CONTRACT]-> Contract
# - Player -[:POSSESSES]-> Statistics
# - Player -[:SUFFERED]-> Injury
# - Team -[:HAS_PLAYER]-> Player
# - Team -[:CURRENT_TEAM]-> Player
#
#
#     Use the schema above to generate a Cypher query that answers the given question.
#     Make the query flexible by using case-insensitive matching and partial string matching where appropriate.
#     Focus on searching player statistics, contracts, and team details.
#
#     Now, generate a Cypher query for the following question:
#
#     Question: Who are the top 5 players in the 2023-24 season based on assist total?
#
#     Cypher Query:
#
# Extracted Cypher Query:
# MATCH (p:Player)-[:PARTICIPATED_IN]->(s:Season {name: "2023-24"})
# MATCH (p)-[:POSSESSES]->(stats:Statistics)
# RETURN p.name AS player, stats.assists_total AS assists
# ORDER BY stats.assists_total DESC
# LIMIT 5
# Original Query Before Per-Game Calculations:
# MATCH (p:Player)-[:PARTICIPATED_IN]->(s:Season {name: "2023-24"})
# MATCH (p)-[:POSSESSES]->(stats:Statistics)
# RETURN p.name AS player, stats.assists_total AS assists
# ORDER BY stats.assists_total DESC
# LIMIT 5
# Adjusted Query After Per-Game Calculations:
# MATCH (p:Player)-[:PARTICIPATED_IN]->(s:Season {name: "2023-24"})
# MATCH (p)-[:POSSESSES]->(stats:Statistics)
# RETURN p.name AS player, stats.assists_total AS assists
# ORDER BY stats.assists_total DESC
# LIMIT 5
# Executing adjusted query:
# MATCH (p:Player)-[:PARTICIPATED_IN]->(s:Season {name: "2023-24"})
# MATCH (p)-[:POSSESSES]->(stats:Statistics)
# RETURN p.name AS player, stats.assists_total AS assists
# ORDER BY stats.assists_total DESC
# LIMIT 5
# Executing Query:
# MATCH (p:Player)-[:PARTICIPATED_IN]->(s:Season {name: "2023-24"})
# MATCH (p)-[:POSSESSES]->(stats:Statistics)
# RETURN p.name AS player, stats.assists_total AS assists
# ORDER BY stats.assists_total DESC
# LIMIT 5
# Query Results:
# {'player': 'Russell Westbrook', 'assists': 784.0}
# {'player': 'Russell Westbrook', 'assists': 763.0}
# {'player': 'Tyrese Haliburton', 'assists': 752.0}
# {'player': 'Trae Young', 'assists': 741.0}
# {'player': 'Trae Young', 'assists': 737.0}

# %%
def check_for_nulls(driver):
    """Check for null values in key statistics properties of the database."""
    query = """
    MATCH (stat:Statistics)
    WHERE stat.ppg IS NULL OR stat.assists_total IS NULL OR stat.rebounds_total IS NULL
        OR stat.steals_total IS NULL OR stat.blocks_total IS NULL OR stat.turnovers_total IS NULL
        OR stat.personal_fouls_total IS NULL OR stat.win_shares_total IS NULL
        OR stat.offensive_win_shares_total IS NULL OR stat.defensive_win_shares_total IS NULL
        OR stat.vorp_total IS NULL OR stat.games_played IS NULL
    RETURN stat.player AS player, stat.season AS season,
           stat.ppg, stat.assists_total, stat.rebounds_total, stat.steals_total, stat.blocks_total,
           stat.turnovers_total, stat.personal_fouls_total, stat.win_shares_total, stat.offensive_win_shares_total,
           stat.defensive_win_shares_total, stat.vorp_total, stat.games_played
    """

    print("Executing query to check for null values in statistics...")
    with driver.session() as session:
        result = session.run(query)
        null_results = [record.data() for record in result]
        if not null_results:
            print("No null values found in key statistics properties.")
        else:
            print("Null values found in the following records:")
            for record in null_results:
                print(record)
# Step 11: Run the null-checking function
check_for_nulls(driver)
# Out:
# Executing query to check for null values in statistics...
# No null values found in key statistics properties.

# %%
# Simple test to check LLM's capability
test_prompt = """
Generate a Cypher query to find all players named 'LeBron James'.

Cypher Query:
"""

llm_response = llm([HumanMessage(content=test_prompt)])
print(f"LLM Test Response:\n{llm_response.content}")
# Out:
# LLM Test Response:
# MATCH (p:Player {name: 'LeBron James'})
# RETURN p

# %%
# Simple test to check LLM's capability
test_prompt = """
can you get the top 5 players by PER in a single season from the neo4j data?
"""

llm_response = llm([HumanMessage(content=test_prompt)])
print(f"LLM Test Response:\n{llm_response.content}")
# Out:
# LLM Test Response:
# To get the top 5 players by PER (Player Efficiency Rating) in a single season from the Neo4j data, I'll use Cypher query. Here's how:
# ```cypher
# MATCH (p:Player)-[:PLAYS_IN]->(t:Team)
# WHERE p.season = '2019-20'
# WITH p, t
# ORDER BY p.per DESC
# LIMIT 5
# RETURN p.name AS player_name, p.per AS per_rating
# ```
# This query:
#
# 1. Matches players (`p`) who played in the `2019-20` season.
# 2. Filters to only include players with a valid PER rating.
# 3. Orders the results by PER in descending order (highest first).
# 4. Limits the results to the top 5 players.
# 5. Returns the player's name and their PER rating.
#
# Running this query would give you the top 5 players by PER in the `2019-20` season from the Neo4j data.
